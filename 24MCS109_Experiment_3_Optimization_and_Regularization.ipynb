# %% [markdown]
# <a href="https://colab.research.google.com/github/JatinVardhan/Deep_Learning_and_Data_Analytics_Lab/blob/master/24MCS109_Experiment_3_Optimization_and_Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experiment 3: Optimization and Regularization**
#
#
# ## Abstract
#
# In this experiment, we investigate optimization and regularization techniques for training a neural network to recognize handwritten digits using the USPS dataset. The network features a 256-unit input layer, one hidden layer with logistic (sigmoid) activation, dropout for regularization, and a 10-way softmax output layer. We explore efficient optimization via gradient descent with momentum and examine various regularization strategies—including dropout and L2 weight decay—to enhance generalization. Additionally, we experiment with the number of hidden units and employ early stopping. All experimental runs are logged and visualized using Weights & Biases (wandb) to facilitate a data–driven hyperparameter search. Our results indicate that a carefully tuned hidden layer size, moderate weight decay, and early stopping lead to improved classification performance on the USPS dataset.

# %% [markdown]
# ## 1. Introduction
#
# Handwritten digit recognition is a classic problem in machine learning, with applications ranging from postal code recognition to bank check processing. In this experiment, we focus on the USPS dataset, which provides grayscale images of handwritten digits. The dataset is split into three parts:
# - **Training Data:** 1,000 samples
# - **Validation Data:** 1,000 samples
# - **Test Data:** The remaining approximately 9,000 samples
#
# Each image is represented by a 256-dimensional vector (each element corresponding to one pixel), and the goal is to classify the digit (0–9) represented by the image.
#
# Our neural network model consists of:
# - An **input layer** of 256 units.
# - **One hidden layer** with logistic (sigmoid) activation functions.
# - **Dropout** is applied after the hidden layer as a regularization technique.
# - A **10-unit output layer** that produces logits for a 10-way softmax classification.
#
# The loss function is **cross-entropy loss**, and we use **Stochastic Gradient Descent (SGD) with momentum** as the optimizer. We systematically investigate:
# 1. A baseline configuration with no weight decay.
# 2. The effect of different L2 weight decay coefficients on generalization.
# 3. The effect of varying the number of hidden units (model parameters) on validation performance.
# 4. The benefits of early stopping combined with an optimal hidden layer size.

# %% [markdown]
# ## 2. Weights & Biases (wandb) Integration
#
# Weights & Biases (wandb) is a powerful tool for experiment tracking, visualization, and collaboration. In this experiment, wandb is used to log metrics (e.g., training/validation loss and accuracy) for every run, compare different hyperparameter settings, and visualize run history. Key wandb functionalities include:
# - **Run Initialization and Login:**
#   Before starting any experiment, you create an account on [wandb.ai](https://wandb.ai) and log in from Colab using `wandb.login()`. This associates your experiments with your wandb dashboard.
# - **Experiment Logging:**
#   As the training proceeds, metrics such as loss and accuracy are logged via `wandb.log()`. These metrics appear in real time on the wandb dashboard, enabling you to monitor performance across epochs.
# - **Run Summary and History:**
#   At the end of each experiment, a run summary (including epoch count, final training/validation loss, and accuracy) is automatically generated and stored on your wandb dashboard.
# - **Team/Entity Setup:**
#   Depending on your account type (personal or team), you may need to specify an entity when initializing wandb. For instance, if your project is under a team, use the team’s entity name.

# %%
# !pip install wandb -qU

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: 24mcs109 (24mcs109-national-institute-of-technology-hamirpur) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import wandb

# Define a run identifier (you can increment this as needed)
run = 1

wandb.init(
    project="usps-digit-classification",
    name=f"experiment_{run}",
    config={
        "hidden_units": 128,  # Default hidden units; you can override in each experiment
        "dropout_rate": 0.5,
        "learning_rate": 0.40,
        "momentum": 0.9,
        "num_epochs": 100,
        "batch_size": 100,
        "dataset": "USPS",
        "architecture": "SimpleNN with one logistic hidden layer and dropout",
        "optimizer": "SGD with momentum"
    }
)
# Out:
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/content/wandb/run-20250216_202315-bi8bza70</code>
# Syncing run <strong><a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/bi8bza70' target="_blank">experiment_1</a></strong> to <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification</a>
#  View run at <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/bi8bza70' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/bi8bza70</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/bi8bza70?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ## 3. Data Loading and Preprocessing
#
# The USPS dataset is stored in an HDF5 file on Google Drive. In the next cell, we mount the drive, load the dataset, normalize the images, shuffle the data, and split it into 1,000 training samples, 1,000 validation samples, and the remaining test samples.
# - **Data Source:** USPS dataset from [Kaggle](https://www.kaggle.com/datasets/bistaumanga/usps-dataset).
# - **Preprocessing:**
#   The images (256-dimensional vectors) are normalized to the [0, 1] range.
# - **Splitting:**
#   The dataset is partitioned into:
#   - 1,000 samples for training,
#   - 1,000 samples for validation,
#   - Approximately 9,000 samples for testing.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import h5py
import numpy as np

# Define the path to your HDF5 file.
path = "/content/drive/My Drive/Colab Notebooks/usps.h5"

# Open the HDF5 file and load the data.
with h5py.File(path, 'r') as hf:
    train_group = hf.get('train')
    X_tr_full = train_group.get('data')[:]     # e.g., shape: (7291, 256)
    y_tr_full = train_group.get('target')[:]     # e.g., shape: (7291,)

    test_group = hf.get('test')
    X_te = test_group.get('data')[:]             # e.g., shape: (2007, 256)
    y_te = test_group.get('target')[:]           # e.g., shape: (2007,)

print("Train data shape:", X_tr_full.shape)
print("Train target shape:", y_tr_full.shape)
print("Test data shape:", X_te.shape)
print("Test target shape:", y_te.shape)

# Convert to float32 and normalize if necessary.
X_tr_full = X_tr_full.astype(np.float32)
X_te = X_te.astype(np.float32)
if X_tr_full.max() > 1.0:
    X_tr_full /= 255.0
if X_te.max() > 1.0:
    X_te /= 255.0

# Shuffle the training data.
np.random.seed(42)
indices = np.random.permutation(len(X_tr_full))
X_tr_full = X_tr_full[indices]
y_tr_full = y_tr_full[indices]

# Split training data: first 1,000 for training, next 1,000 for validation.
X_train = X_tr_full[:1000]
y_train = y_tr_full[:1000]
X_val   = X_tr_full[1000:2000]
y_val   = y_tr_full[1000:2000]

# For testing, use the provided test split.
X_test = X_te
y_test = y_te

print(f"Final split shapes:\n X_train: {X_train.shape}, X_val: {X_val.shape}, X_test: {X_test.shape}")
# Out:
# Train data shape: (7291, 256)
# Train target shape: (7291,)
# Test data shape: (2007, 256)
# Test target shape: (2007,)
# Final split shapes:
#  X_train: (1000, 256), X_val: (1000, 256), X_test: (2007, 256)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class USPSDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Create dataset objects for train, validation, and test.
train_dataset = USPSDataset(X_train, y_train)
val_dataset   = USPSDataset(X_val, y_val)
test_dataset  = USPSDataset(X_test, y_test)

# %% [markdown]
# ## 4. Model Definition
#
# We define a simple neural network with:
# - **Input layer:** 256 units (one per pixel).
# - **Hidden layer:** A single hidden layer with logistic (sigmoid) activation. The number of units is tunable.
# - **Regularization:** Dropout is applied after the hidden layer.
# - **Output layer:** 10 units corresponding to the 10 digits (0–9).
# The cross–entropy loss function is used, which internally applies a softmax on the output logits.

# %%
import torch.nn as nn

class SimpleNN(nn.Module):
    def __init__(self, hidden_units=128, dropout_rate=0.5):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(256, hidden_units)
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_units, 10)  # 10 outputs for digits 0-9

    def forward(self, x):
        x = self.fc1(x)
        x = torch.sigmoid(x)  # Logistic activation
        x = self.dropout(x)   # Dropout for regularization
        x = self.fc2(x)       # Output logits (CrossEntropyLoss applies softmax internally)
        return x

# %% [markdown]
# ## 5. Training and Evaluation Functions
#
# We define helper functions to perform one epoch of training and evaluation. These functions compute the cross–entropy loss and classification accuracy.

# %%
import torch.optim as optim

# Loss function
criterion = nn.CrossEntropyLoss()

# Use GPU if available.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training for one epoch.
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    return total_loss / total, correct / total

# Evaluation (validation or test)
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    return total_loss / total, correct / total

# %% [markdown]
# ## 6. Experiment Helper Function
#
# The `run_experiment(config)` function encapsulates the training process for a given hyperparameter configuration. It creates data loaders, instantiates the model, sets up the optimizer (with optional weight decay), and trains the model while logging metrics to wandb. Early stopping is applied if a `"patience"` value is provided.

# %%
import matplotlib.pyplot as plt

def run_experiment(config):
    """
    Runs training with the specified configuration.
    config keys:
      - hidden_units (int)
      - weight_decay (float)
      - learning_rate (float)
      - momentum (float)
      - num_epochs (int)
      - batch_size (int)
      - dropout_rate (optional, float)
      - patience (optional, int): early stopping patience.
    """
    # Create new DataLoaders.
    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader   = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

    # Use dropout_rate from config if provided; otherwise default to 0.5.
    dropout_rate = config.get('dropout_rate', 0.5)
    model = SimpleNN(hidden_units=config['hidden_units'], dropout_rate=dropout_rate)
    model.to(device)

    # Set up optimizer with weight decay.
    optimizer = optim.SGD(
        model.parameters(),
        lr=config['learning_rate'],
        momentum=config['momentum'],
        weight_decay=config['weight_decay']
    )

    best_val_loss = float('inf')
    epochs_without_improvement = 0
    patience = config.get('patience', None)  # No early stopping if not provided.

    epoch_losses = []
    epoch_accs = []

    for epoch in range(config['num_epochs']):
        train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc = evaluate(model, val_loader, criterion, device)
        epoch_losses.append(val_loss)
        epoch_accs.append(val_acc)

        print(f"Epoch {epoch+1}/{config['num_epochs']}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}, Val Acc={val_acc:.4f}")

        # Log per-epoch metrics.
        wandb.log({
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_accuracy": train_acc,
            "val_loss": val_loss,
            "val_accuracy": val_acc
        })

        # Always update best_val_loss.
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_without_improvement = 0
        else:
            if patience is not None:
                epochs_without_improvement += 1
                if epochs_without_improvement >= patience:
                    print("Early stopping triggered!")
                    break

    return best_val_loss, epoch_losses, epoch_accs

# %% [markdown]
# ## 7. Experimental Setup

# %% [markdown]
# ### **A. Baseline :**
#    Configuration with 200 hidden units, zero weight decay, 100 epochs (≈1000 iterations with batch size 100), learning rate of 0.40, momentum of 0.9, and no early stopping.

# %%
# Experiment 1 configuration
exp1_config = {
    'hidden_units': 200,
    'dropout_rate': 0.5,  # added dropout_rate
    'weight_decay': 0.0,
    'learning_rate': 0.40,
    'momentum': 0.9,
    'num_epochs': 100,
    'batch_size': 100
}

print("Starting Experiment 1: Basic Configuration")
val_loss_exp1, epoch_losses_exp1, epoch_accs_exp1 = run_experiment(exp1_config)
print(f"Experiment 1 Final Validation Loss: {val_loss_exp1:.4f}")

import matplotlib.pyplot as plt
from PIL import Image
import io

# Plot the validation loss curve.
plt.figure(figsize=(8, 5))
plt.plot(epoch_losses_exp1, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Experiment 1: Validation Loss Curve')
plt.grid(True)
plt.show()

# Save the figure to a BytesIO buffer.
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)

# Open the image with PIL and log it to wandb.
img = Image.open(buf)
wandb.log({"Exp1_Val_Loss_Curve": wandb.Image(img)})

# Optionally, simulate logging some additional metrics (like in your sample snippet)
import random
epochs = 10
offset = random.random() / 5
for epoch in range(2, epochs):
    acc = 1 - 2 ** -epoch - random.random() / epoch - offset
    loss = 2 ** -epoch + random.random() / epoch + offset
    wandb.log({"simulated_acc": acc, "simulated_loss": loss})

# Mark the run as finished.
wandb.finish()
# Out:
# Starting Experiment 1: Basic Configuration
# Epoch 1/100: Train Loss=3.3306, Val Loss=2.0554, Val Acc=0.3730
# Epoch 2/100: Train Loss=1.7121, Val Loss=1.3237, Val Acc=0.5080
# Epoch 3/100: Train Loss=1.1293, Val Loss=0.7591, Val Acc=0.8110
# Epoch 4/100: Train Loss=0.7366, Val Loss=0.5110, Val Acc=0.8540
# Epoch 5/100: Train Loss=0.4866, Val Loss=0.3631, Val Acc=0.9010
# Epoch 6/100: Train Loss=0.3975, Val Loss=0.3216, Val Acc=0.9060
# Epoch 7/100: Train Loss=0.3162, Val Loss=0.2959, Val Acc=0.9200
# Epoch 8/100: Train Loss=0.2738, Val Loss=0.2683, Val Acc=0.9290
# Epoch 9/100: Train Loss=0.2442, Val Loss=0.2660, Val Acc=0.9280
# Epoch 10/100: Train Loss=0.1972, Val Loss=0.2485, Val Acc=0.9300
# Epoch 11/100: Train Loss=0.1954, Val Loss=0.2494, Val Acc=0.9300
# Epoch 12/100: Train Loss=0.1799, Val Loss=0.2414, Val Acc=0.9310
# Epoch 13/100: Train Loss=0.1446, Val Loss=0.2326, Val Acc=0.9340
# Epoch 14/100: Train Loss=0.1498, Val Loss=0.2248, Val Acc=0.9330
# Epoch 15/100: Train Loss=0.1308, Val Loss=0.2317, Val Acc=0.9320
# Epoch 16/100: Train Loss=0.1280, Val Loss=0.2272, Val Acc=0.9330
# Epoch 17/100: Train Loss=0.1153, Val Loss=0.2359, Val Acc=0.9310
# Epoch 18/100: Train Loss=0.1176, Val Loss=0.2357, Val Acc=0.9370
# Epoch 19/100: Train Loss=0.1198, Val Loss=0.2219, Val Acc=0.9360
# Epoch 20/100: Train Loss=0.1047, Val Loss=0.2180, Val Acc=0.9370
# Epoch 21/100: Train Loss=0.0959, Val Loss=0.2288, Val Acc=0.9390
# Epoch 22/100: Train Loss=0.0826, Val Loss=0.2222, Val Acc=0.9370
# Epoch 23/100: Train Loss=0.0877, Val Loss=0.2316, Val Acc=0.9380
# Epoch 24/100: Train Loss=0.0902, Val Loss=0.2282, Val Acc=0.9390
# Epoch 25/100: Train Loss=0.0863, Val Loss=0.2250, Val Acc=0.9400
# Epoch 26/100: Train Loss=0.0743, Val Loss=0.2350, Val Acc=0.9360
# Epoch 27/100: Train Loss=0.0592, Val Loss=0.2329, Val Acc=0.9380
# Epoch 28/100: Train Loss=0.0667, Val Loss=0.2382, Val Acc=0.9360
# Epoch 29/100: Train Loss=0.0717, Val Loss=0.2304, Val Acc=0.9390
# Epoch 30/100: Train Loss=0.0624, Val Loss=0.2271, Val Acc=0.9380
# Epoch 31/100: Train Loss=0.0456, Val Loss=0.2326, Val Acc=0.9390
# Epoch 32/100: Train Loss=0.0555, Val Loss=0.2431, Val Acc=0.9370
# Epoch 33/100: Train Loss=0.0557, Val Loss=0.2450, Val Acc=0.9370
# Epoch 34/100: Train Loss=0.0389, Val Loss=0.2393, Val Acc=0.9360
# Epoch 35/100: Train Loss=0.0483, Val Loss=0.2378, Val Acc=0.9380
# Epoch 36/100: Train Loss=0.0503, Val Loss=0.2414, Val Acc=0.9410
# Epoch 37/100: Train Loss=0.0474, Val Loss=0.2381, Val Acc=0.9420
# Epoch 38/100: Train Loss=0.0552, Val Loss=0.2392, Val Acc=0.9410
# Epoch 39/100: Train Loss=0.0400, Val Loss=0.2335, Val Acc=0.9400
# Epoch 40/100: Train Loss=0.0465, Val Loss=0.2439, Val Acc=0.9380
# Epoch 41/100: Train Loss=0.0272, Val Loss=0.2494, Val Acc=0.9410
# Epoch 42/100: Train Loss=0.0423, Val Loss=0.2557, Val Acc=0.9360
# Epoch 43/100: Train Loss=0.0410, Val Loss=0.2612, Val Acc=0.9380
# Epoch 44/100: Train Loss=0.0425, Val Loss=0.2506, Val Acc=0.9420
# Epoch 45/100: Train Loss=0.0481, Val Loss=0.2411, Val Acc=0.9420
# Epoch 46/100: Train Loss=0.0466, Val Loss=0.2573, Val Acc=0.9360
# Epoch 47/100: Train Loss=0.0407, Val Loss=0.2560, Val Acc=0.9380
# Epoch 48/100: Train Loss=0.0372, Val Loss=0.2505, Val Acc=0.9390
# Epoch 49/100: Train Loss=0.0342, Val Loss=0.2488, Val Acc=0.9410
# Epoch 50/100: Train Loss=0.0332, Val Loss=0.2598, Val Acc=0.9380
# Epoch 51/100: Train Loss=0.0382, Val Loss=0.2653, Val Acc=0.9410
# Epoch 52/100: Train Loss=0.0302, Val Loss=0.2587, Val Acc=0.9390
# Epoch 53/100: Train Loss=0.0337, Val Loss=0.2629, Val Acc=0.9410
# Epoch 54/100: Train Loss=0.0272, Val Loss=0.2639, Val Acc=0.9420
# Epoch 55/100: Train Loss=0.0352, Val Loss=0.2603, Val Acc=0.9380
# Epoch 56/100: Train Loss=0.0347, Val Loss=0.2558, Val Acc=0.9460
# Epoch 57/100: Train Loss=0.0319, Val Loss=0.2623, Val Acc=0.9390
# Epoch 58/100: Train Loss=0.0368, Val Loss=0.2479, Val Acc=0.9400
# Epoch 59/100: Train Loss=0.0359, Val Loss=0.2491, Val Acc=0.9420
# Epoch 60/100: Train Loss=0.0245, Val Loss=0.2565, Val Acc=0.9420
# Epoch 61/100: Train Loss=0.0260, Val Loss=0.2563, Val Acc=0.9440
# Epoch 62/100: Train Loss=0.0273, Val Loss=0.2642, Val Acc=0.9380
# Epoch 63/100: Train Loss=0.0283, Val Loss=0.2810, Val Acc=0.9400
# Epoch 64/100: Train Loss=0.0291, Val Loss=0.2741, Val Acc=0.9410
# Epoch 65/100: Train Loss=0.0225, Val Loss=0.2659, Val Acc=0.9360
# Epoch 66/100: Train Loss=0.0283, Val Loss=0.2618, Val Acc=0.9390
# Epoch 67/100: Train Loss=0.0236, Val Loss=0.2638, Val Acc=0.9420
# Epoch 68/100: Train Loss=0.0167, Val Loss=0.2785, Val Acc=0.9400
# Epoch 69/100: Train Loss=0.0229, Val Loss=0.2772, Val Acc=0.9380
# Epoch 70/100: Train Loss=0.0208, Val Loss=0.2728, Val Acc=0.9420
# Epoch 71/100: Train Loss=0.0267, Val Loss=0.2669, Val Acc=0.9420
# Epoch 72/100: Train Loss=0.0211, Val Loss=0.2674, Val Acc=0.9390
# Epoch 73/100: Train Loss=0.0248, Val Loss=0.2701, Val Acc=0.9390
# Epoch 74/100: Train Loss=0.0164, Val Loss=0.2715, Val Acc=0.9400
# Epoch 75/100: Train Loss=0.0221, Val Loss=0.2795, Val Acc=0.9410
# Epoch 76/100: Train Loss=0.0215, Val Loss=0.2781, Val Acc=0.9390
# Epoch 77/100: Train Loss=0.0198, Val Loss=0.2774, Val Acc=0.9410
# Epoch 78/100: Train Loss=0.0183, Val Loss=0.2777, Val Acc=0.9400
# Epoch 79/100: Train Loss=0.0197, Val Loss=0.2719, Val Acc=0.9390
# Epoch 80/100: Train Loss=0.0222, Val Loss=0.2780, Val Acc=0.9390
# Epoch 81/100: Train Loss=0.0203, Val Loss=0.2776, Val Acc=0.9440
# Epoch 82/100: Train Loss=0.0208, Val Loss=0.2742, Val Acc=0.9430
# Epoch 83/100: Train Loss=0.0188, Val Loss=0.2737, Val Acc=0.9420
# Epoch 84/100: Train Loss=0.0202, Val Loss=0.2682, Val Acc=0.9400
# Epoch 85/100: Train Loss=0.0101, Val Loss=0.2705, Val Acc=0.9380
# Epoch 86/100: Train Loss=0.0142, Val Loss=0.2817, Val Acc=0.9400
# Epoch 87/100: Train Loss=0.0154, Val Loss=0.2832, Val Acc=0.9360
# Epoch 88/100: Train Loss=0.0142, Val Loss=0.2955, Val Acc=0.9390
# Epoch 89/100: Train Loss=0.0225, Val Loss=0.2922, Val Acc=0.9410
# Epoch 90/100: Train Loss=0.0197, Val Loss=0.2839, Val Acc=0.9390
# Epoch 91/100: Train Loss=0.0196, Val Loss=0.2815, Val Acc=0.9400
# Epoch 92/100: Train Loss=0.0220, Val Loss=0.2810, Val Acc=0.9380
# Epoch 93/100: Train Loss=0.0119, Val Loss=0.2848, Val Acc=0.9420
# Epoch 94/100: Train Loss=0.0120, Val Loss=0.2876, Val Acc=0.9410
# Epoch 95/100: Train Loss=0.0155, Val Loss=0.2833, Val Acc=0.9420
# Epoch 96/100: Train Loss=0.0116, Val Loss=0.2789, Val Acc=0.9390
# Epoch 97/100: Train Loss=0.0222, Val Loss=0.2821, Val Acc=0.9400
# Epoch 98/100: Train Loss=0.0172, Val Loss=0.2892, Val Acc=0.9400
# Epoch 99/100: Train Loss=0.0120, Val Loss=0.2977, Val Acc=0.9380
# Epoch 100/100: Train Loss=0.0128, Val Loss=0.2825, Val Acc=0.9430
# Experiment 1 Final Validation Loss: 0.2180
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>simulated_acc</td><td>▁▃▄▇▄█▆█</td></tr><tr><td>simulated_loss</td><td>█▃▂▂▁▁▁▂</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇▇██████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▅▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▆▇▇████████████████████████████████████</td></tr><tr><td>val_loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>simulated_acc</td><td>0.85602</td></tr><tr><td>simulated_loss</td><td>0.21867</td></tr><tr><td>train_accuracy</td><td>0.997</td></tr><tr><td>train_loss</td><td>0.01279</td></tr><tr><td>val_accuracy</td><td>0.943</td></tr><tr><td>val_loss</td><td>0.28252</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1</strong> at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/bi8bza70' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/bi8bza70</a><br> View project at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250216_202315-bi8bza70/logs</code>

# %% [markdown]
# **RESULT ANALYSIS :**
#
# - **Training Dynamics:**
#   The model converged quickly with a steady decrease in training loss, reaching a very low training loss of approximately **0.012** and an excellent training accuracy of **99.7%**.
#
# - **Validation Performance:**
#   The validation loss reached a minimum of **~0.2100** during training, and the final validation accuracy is around **94.3%**. These results indicate that the model generalizes well despite the high training accuracy.
#
# - **Overall Assessment:**
#   The use of SGD with momentum (learning rate = 0.40, momentum = 0.9) enabled rapid convergence, while dropout (with a dropout rate of 0.5) provided sufficient regularization to prevent overfitting. The run history from wandb confirms that the model's performance remains stable over 100 epochs, making this configuration a promising baseline for further hyperparameter tuning.
#
# *View the detailed run metrics on the wandb dashboard for more insights.*

# %% [markdown]
#  ### **B. Weight Decay Investigation :**
#    Testing different L2 weight decay coefficients: 0.0, 0.0001, 0.001, 0.01, 1, 2, and 5.

# %%
import matplotlib.pyplot as plt

# Reinitialize wandb if no active run exists.
if wandb.run is None:
    wandb.init(
        project="usps-digit-classification",
        settings=wandb.Settings(init_timeout=600)
    )

weight_decay_values = [0.0, 0.0001, 0.001, 0.01, 1, 2, 5]
results_wd = {}

for wd in weight_decay_values:
    config_wd = {
        'hidden_units': 200,
        'dropout_rate': 0.5,
        'weight_decay': wd,
        'learning_rate': 0.40,
        'momentum': 0.9,
        'num_epochs': 100,
        'batch_size': 100
    }
    print(f"\nRunning Experiment 2 with weight decay = {wd}")
    val_loss, _, _ = run_experiment(config_wd)
    results_wd[wd] = val_loss
    print(f"WD={wd} -> Val Loss: {val_loss:.4f}")
    wandb.log({f"Exp2_ValLoss_WD_{wd}": val_loss})

# (Optional) Locally display the plot:
plt.figure(figsize=(8, 5))
# If any weight decay is zero, use linear scale; otherwise, log scale can be used.
nonzero_wds = [wd for wd in weight_decay_values if wd > 0]
if len(nonzero_wds) == len(weight_decay_values):
    plt.xscale('log')
else:
    plt.xscale('linear')
plt.plot(weight_decay_values, [results_wd[wd] for wd in weight_decay_values], marker='o')
plt.xlabel('Weight Decay Coefficient')
plt.ylabel('Validation Loss')
plt.title('Experiment 2: Val Loss vs. Weight Decay')
plt.grid(True)
plt.show()

wandb.finish()  # End this run when done.
# Out:
# Running Experiment 2 with weight decay = 0.0
# Epoch 1/100: Train Loss=2.8823, Val Loss=2.8195, Val Acc=0.3660
# Epoch 2/100: Train Loss=1.7055, Val Loss=1.1691, Val Acc=0.6130
# Epoch 3/100: Train Loss=0.8336, Val Loss=0.5626, Val Acc=0.8420
# Epoch 4/100: Train Loss=0.5318, Val Loss=0.4118, Val Acc=0.8600
# Epoch 5/100: Train Loss=0.3942, Val Loss=0.3293, Val Acc=0.8970
# Epoch 6/100: Train Loss=0.3112, Val Loss=0.2983, Val Acc=0.9100
# Epoch 7/100: Train Loss=0.2588, Val Loss=0.2843, Val Acc=0.9220
# Epoch 8/100: Train Loss=0.2105, Val Loss=0.2497, Val Acc=0.9300
# Epoch 9/100: Train Loss=0.1991, Val Loss=0.2431, Val Acc=0.9330
# Epoch 10/100: Train Loss=0.1693, Val Loss=0.2409, Val Acc=0.9260
# Epoch 11/100: Train Loss=0.1498, Val Loss=0.2424, Val Acc=0.9320
# Epoch 12/100: Train Loss=0.1420, Val Loss=0.2275, Val Acc=0.9410
# Epoch 13/100: Train Loss=0.1335, Val Loss=0.2360, Val Acc=0.9330
# Epoch 14/100: Train Loss=0.1382, Val Loss=0.2378, Val Acc=0.9330
# Epoch 15/100: Train Loss=0.1312, Val Loss=0.2238, Val Acc=0.9330
# Epoch 16/100: Train Loss=0.0999, Val Loss=0.2330, Val Acc=0.9330
# Epoch 17/100: Train Loss=0.0896, Val Loss=0.2305, Val Acc=0.9360
# Epoch 18/100: Train Loss=0.0844, Val Loss=0.2336, Val Acc=0.9280
# Epoch 19/100: Train Loss=0.0802, Val Loss=0.2495, Val Acc=0.9310
# Epoch 20/100: Train Loss=0.0974, Val Loss=0.2425, Val Acc=0.9330
# Epoch 21/100: Train Loss=0.0812, Val Loss=0.2326, Val Acc=0.9370
# Epoch 22/100: Train Loss=0.0666, Val Loss=0.2429, Val Acc=0.9360
# Epoch 23/100: Train Loss=0.0687, Val Loss=0.2360, Val Acc=0.9360
# Epoch 24/100: Train Loss=0.0550, Val Loss=0.2339, Val Acc=0.9370
# Epoch 25/100: Train Loss=0.0553, Val Loss=0.2405, Val Acc=0.9320
# Epoch 26/100: Train Loss=0.0597, Val Loss=0.2307, Val Acc=0.9350
# Epoch 27/100: Train Loss=0.0563, Val Loss=0.2420, Val Acc=0.9320
# Epoch 28/100: Train Loss=0.0496, Val Loss=0.2405, Val Acc=0.9360
# Epoch 29/100: Train Loss=0.0446, Val Loss=0.2414, Val Acc=0.9350
# Epoch 30/100: Train Loss=0.0544, Val Loss=0.2435, Val Acc=0.9340
# Epoch 31/100: Train Loss=0.0414, Val Loss=0.2449, Val Acc=0.9330
# Epoch 32/100: Train Loss=0.0486, Val Loss=0.2474, Val Acc=0.9340
# Epoch 33/100: Train Loss=0.0383, Val Loss=0.2493, Val Acc=0.9370
# Epoch 34/100: Train Loss=0.0501, Val Loss=0.2480, Val Acc=0.9320
# Epoch 35/100: Train Loss=0.0446, Val Loss=0.2471, Val Acc=0.9330
# Epoch 36/100: Train Loss=0.0483, Val Loss=0.2445, Val Acc=0.9350
# Epoch 37/100: Train Loss=0.0359, Val Loss=0.2533, Val Acc=0.9320
# Epoch 38/100: Train Loss=0.0340, Val Loss=0.2599, Val Acc=0.9360
# Epoch 39/100: Train Loss=0.0288, Val Loss=0.2628, Val Acc=0.9330
# Epoch 40/100: Train Loss=0.0375, Val Loss=0.2542, Val Acc=0.9370
# Epoch 41/100: Train Loss=0.0292, Val Loss=0.2513, Val Acc=0.9400
# Epoch 42/100: Train Loss=0.0393, Val Loss=0.2588, Val Acc=0.9370
# Epoch 43/100: Train Loss=0.0367, Val Loss=0.2557, Val Acc=0.9370
# Epoch 44/100: Train Loss=0.0385, Val Loss=0.2577, Val Acc=0.9350
# Epoch 45/100: Train Loss=0.0282, Val Loss=0.2636, Val Acc=0.9360
# Epoch 46/100: Train Loss=0.0306, Val Loss=0.2590, Val Acc=0.9360
# Epoch 47/100: Train Loss=0.0335, Val Loss=0.2637, Val Acc=0.9350
# Epoch 48/100: Train Loss=0.0326, Val Loss=0.2558, Val Acc=0.9350
# Epoch 49/100: Train Loss=0.0360, Val Loss=0.2573, Val Acc=0.9370
# Epoch 50/100: Train Loss=0.0280, Val Loss=0.2514, Val Acc=0.9360
# Epoch 51/100: Train Loss=0.0298, Val Loss=0.2606, Val Acc=0.9330
# Epoch 52/100: Train Loss=0.0169, Val Loss=0.2622, Val Acc=0.9330
# Epoch 53/100: Train Loss=0.0231, Val Loss=0.2636, Val Acc=0.9350
# Epoch 54/100: Train Loss=0.0257, Val Loss=0.2648, Val Acc=0.9370
# Epoch 55/100: Train Loss=0.0227, Val Loss=0.2664, Val Acc=0.9340
# Epoch 56/100: Train Loss=0.0232, Val Loss=0.2601, Val Acc=0.9360
# Epoch 57/100: Train Loss=0.0241, Val Loss=0.2572, Val Acc=0.9370
# Epoch 58/100: Train Loss=0.0251, Val Loss=0.2551, Val Acc=0.9390
# Epoch 59/100: Train Loss=0.0239, Val Loss=0.2583, Val Acc=0.9380
# Epoch 60/100: Train Loss=0.0237, Val Loss=0.2693, Val Acc=0.9360
# Epoch 61/100: Train Loss=0.0194, Val Loss=0.2705, Val Acc=0.9370
# Epoch 62/100: Train Loss=0.0246, Val Loss=0.2720, Val Acc=0.9340
# Epoch 63/100: Train Loss=0.0236, Val Loss=0.2678, Val Acc=0.9360
# Epoch 64/100: Train Loss=0.0158, Val Loss=0.2662, Val Acc=0.9350
# Epoch 65/100: Train Loss=0.0185, Val Loss=0.2649, Val Acc=0.9370
# Epoch 66/100: Train Loss=0.0235, Val Loss=0.2702, Val Acc=0.9370
# Epoch 67/100: Train Loss=0.0167, Val Loss=0.2788, Val Acc=0.9350
# Epoch 68/100: Train Loss=0.0259, Val Loss=0.2752, Val Acc=0.9360
# Epoch 69/100: Train Loss=0.0244, Val Loss=0.2688, Val Acc=0.9380
# Epoch 70/100: Train Loss=0.0159, Val Loss=0.2744, Val Acc=0.9380
# Epoch 71/100: Train Loss=0.0198, Val Loss=0.2682, Val Acc=0.9390
# Epoch 72/100: Train Loss=0.0163, Val Loss=0.2694, Val Acc=0.9390
# Epoch 73/100: Train Loss=0.0134, Val Loss=0.2748, Val Acc=0.9370
# Epoch 74/100: Train Loss=0.0224, Val Loss=0.2696, Val Acc=0.9360
# Epoch 75/100: Train Loss=0.0181, Val Loss=0.2654, Val Acc=0.9370
# Epoch 76/100: Train Loss=0.0216, Val Loss=0.2713, Val Acc=0.9340
# Epoch 77/100: Train Loss=0.0106, Val Loss=0.2769, Val Acc=0.9340
# Epoch 78/100: Train Loss=0.0196, Val Loss=0.2897, Val Acc=0.9300
# Epoch 79/100: Train Loss=0.0140, Val Loss=0.2839, Val Acc=0.9350
# Epoch 80/100: Train Loss=0.0200, Val Loss=0.2682, Val Acc=0.9360
# Epoch 81/100: Train Loss=0.0174, Val Loss=0.2655, Val Acc=0.9410
# Epoch 82/100: Train Loss=0.0142, Val Loss=0.2685, Val Acc=0.9390
# Epoch 83/100: Train Loss=0.0120, Val Loss=0.2744, Val Acc=0.9360
# Epoch 84/100: Train Loss=0.0152, Val Loss=0.2774, Val Acc=0.9330
# Epoch 85/100: Train Loss=0.0198, Val Loss=0.2866, Val Acc=0.9330
# Epoch 86/100: Train Loss=0.0211, Val Loss=0.2790, Val Acc=0.9370
# Epoch 87/100: Train Loss=0.0181, Val Loss=0.2801, Val Acc=0.9380
# Epoch 88/100: Train Loss=0.0146, Val Loss=0.2789, Val Acc=0.9350
# Epoch 89/100: Train Loss=0.0110, Val Loss=0.2794, Val Acc=0.9350
# Epoch 90/100: Train Loss=0.0147, Val Loss=0.2814, Val Acc=0.9360
# Epoch 91/100: Train Loss=0.0119, Val Loss=0.2835, Val Acc=0.9350
# Epoch 92/100: Train Loss=0.0139, Val Loss=0.2794, Val Acc=0.9370
# Epoch 93/100: Train Loss=0.0106, Val Loss=0.2792, Val Acc=0.9350
# Epoch 94/100: Train Loss=0.0111, Val Loss=0.2810, Val Acc=0.9370
# Epoch 95/100: Train Loss=0.0119, Val Loss=0.2847, Val Acc=0.9350
# Epoch 96/100: Train Loss=0.0171, Val Loss=0.2753, Val Acc=0.9390
# Epoch 97/100: Train Loss=0.0136, Val Loss=0.2790, Val Acc=0.9390
# Epoch 98/100: Train Loss=0.0132, Val Loss=0.2768, Val Acc=0.9390
# Epoch 99/100: Train Loss=0.0109, Val Loss=0.2750, Val Acc=0.9400
# Epoch 100/100: Train Loss=0.0125, Val Loss=0.2744, Val Acc=0.9410
# WD=0.0 -> Val Loss: 0.2238
#
# Running Experiment 2 with weight decay = 0.0001
# Epoch 1/100: Train Loss=3.2671, Val Loss=2.3003, Val Acc=0.3090
# Epoch 2/100: Train Loss=1.7946, Val Loss=1.4074, Val Acc=0.4840
# Epoch 3/100: Train Loss=1.1906, Val Loss=0.8857, Val Acc=0.7460
# Epoch 4/100: Train Loss=0.8107, Val Loss=0.6211, Val Acc=0.8010
# Epoch 5/100: Train Loss=0.6056, Val Loss=0.4593, Val Acc=0.8700
# Epoch 6/100: Train Loss=0.4491, Val Loss=0.3765, Val Acc=0.8930
# Epoch 7/100: Train Loss=0.3873, Val Loss=0.3223, Val Acc=0.9150
# Epoch 8/100: Train Loss=0.3072, Val Loss=0.3009, Val Acc=0.9210
# Epoch 9/100: Train Loss=0.2835, Val Loss=0.2677, Val Acc=0.9260
# Epoch 10/100: Train Loss=0.2477, Val Loss=0.2547, Val Acc=0.9360
# Epoch 11/100: Train Loss=0.2324, Val Loss=0.2623, Val Acc=0.9300
# Epoch 12/100: Train Loss=0.2070, Val Loss=0.2481, Val Acc=0.9340
# Epoch 13/100: Train Loss=0.1841, Val Loss=0.2454, Val Acc=0.9350
# Epoch 14/100: Train Loss=0.1624, Val Loss=0.2565, Val Acc=0.9260
# Epoch 15/100: Train Loss=0.1656, Val Loss=0.2320, Val Acc=0.9320
# Epoch 16/100: Train Loss=0.1714, Val Loss=0.2394, Val Acc=0.9330
# Epoch 17/100: Train Loss=0.1533, Val Loss=0.2381, Val Acc=0.9280
# Epoch 18/100: Train Loss=0.1297, Val Loss=0.2332, Val Acc=0.9360
# Epoch 19/100: Train Loss=0.1306, Val Loss=0.2404, Val Acc=0.9370
# Epoch 20/100: Train Loss=0.1056, Val Loss=0.2350, Val Acc=0.9360
# Epoch 21/100: Train Loss=0.1120, Val Loss=0.2353, Val Acc=0.9340
# Epoch 22/100: Train Loss=0.1109, Val Loss=0.2352, Val Acc=0.9330
# Epoch 23/100: Train Loss=0.1026, Val Loss=0.2419, Val Acc=0.9320
# Epoch 24/100: Train Loss=0.0970, Val Loss=0.2308, Val Acc=0.9360
# Epoch 25/100: Train Loss=0.0930, Val Loss=0.2261, Val Acc=0.9390
# Epoch 26/100: Train Loss=0.0875, Val Loss=0.2291, Val Acc=0.9400
# Epoch 27/100: Train Loss=0.0743, Val Loss=0.2258, Val Acc=0.9380
# Epoch 28/100: Train Loss=0.0790, Val Loss=0.2347, Val Acc=0.9390
# Epoch 29/100: Train Loss=0.0828, Val Loss=0.2362, Val Acc=0.9390
# Epoch 30/100: Train Loss=0.0883, Val Loss=0.2170, Val Acc=0.9380
# Epoch 31/100: Train Loss=0.0831, Val Loss=0.2249, Val Acc=0.9410
# Epoch 32/100: Train Loss=0.0681, Val Loss=0.2431, Val Acc=0.9380
# Epoch 33/100: Train Loss=0.0685, Val Loss=0.2294, Val Acc=0.9390
# Epoch 34/100: Train Loss=0.0658, Val Loss=0.2269, Val Acc=0.9390
# Epoch 35/100: Train Loss=0.0797, Val Loss=0.2408, Val Acc=0.9340
# Epoch 36/100: Train Loss=0.0675, Val Loss=0.2346, Val Acc=0.9360
# Epoch 37/100: Train Loss=0.0504, Val Loss=0.2327, Val Acc=0.9350
# Epoch 38/100: Train Loss=0.0642, Val Loss=0.2259, Val Acc=0.9350
# Epoch 39/100: Train Loss=0.0608, Val Loss=0.2274, Val Acc=0.9360
# Epoch 40/100: Train Loss=0.0564, Val Loss=0.2388, Val Acc=0.9360
# Epoch 41/100: Train Loss=0.0622, Val Loss=0.2473, Val Acc=0.9350
# Epoch 42/100: Train Loss=0.0663, Val Loss=0.2443, Val Acc=0.9310
# Epoch 43/100: Train Loss=0.0591, Val Loss=0.2436, Val Acc=0.9340
# Epoch 44/100: Train Loss=0.0602, Val Loss=0.2365, Val Acc=0.9360
# Epoch 45/100: Train Loss=0.0613, Val Loss=0.2346, Val Acc=0.9420
# Epoch 46/100: Train Loss=0.0599, Val Loss=0.2288, Val Acc=0.9410
# Epoch 47/100: Train Loss=0.0460, Val Loss=0.2267, Val Acc=0.9370
# Epoch 48/100: Train Loss=0.0504, Val Loss=0.2375, Val Acc=0.9360
# Epoch 49/100: Train Loss=0.0591, Val Loss=0.2294, Val Acc=0.9390
# Epoch 50/100: Train Loss=0.0605, Val Loss=0.2284, Val Acc=0.9380
# Epoch 51/100: Train Loss=0.0385, Val Loss=0.2362, Val Acc=0.9350
# Epoch 52/100: Train Loss=0.0349, Val Loss=0.2469, Val Acc=0.9360
# Epoch 53/100: Train Loss=0.0438, Val Loss=0.2399, Val Acc=0.9360
# Epoch 54/100: Train Loss=0.0386, Val Loss=0.2388, Val Acc=0.9400
# Epoch 55/100: Train Loss=0.0392, Val Loss=0.2402, Val Acc=0.9360
# Epoch 56/100: Train Loss=0.0426, Val Loss=0.2519, Val Acc=0.9350
# Epoch 57/100: Train Loss=0.0585, Val Loss=0.2370, Val Acc=0.9380
# Epoch 58/100: Train Loss=0.0399, Val Loss=0.2465, Val Acc=0.9330
# Epoch 59/100: Train Loss=0.0404, Val Loss=0.2461, Val Acc=0.9360
# Epoch 60/100: Train Loss=0.0487, Val Loss=0.2465, Val Acc=0.9380
# Epoch 61/100: Train Loss=0.0383, Val Loss=0.2497, Val Acc=0.9390
# Epoch 62/100: Train Loss=0.0451, Val Loss=0.2454, Val Acc=0.9380
# Epoch 63/100: Train Loss=0.0386, Val Loss=0.2439, Val Acc=0.9370
# Epoch 64/100: Train Loss=0.0468, Val Loss=0.2459, Val Acc=0.9320
# Epoch 65/100: Train Loss=0.0510, Val Loss=0.2526, Val Acc=0.9370
# Epoch 66/100: Train Loss=0.0506, Val Loss=0.2620, Val Acc=0.9360
# Epoch 67/100: Train Loss=0.0474, Val Loss=0.2462, Val Acc=0.9360
# Epoch 68/100: Train Loss=0.0344, Val Loss=0.2465, Val Acc=0.9380
# Epoch 69/100: Train Loss=0.0367, Val Loss=0.2353, Val Acc=0.9380
# Epoch 70/100: Train Loss=0.0425, Val Loss=0.2399, Val Acc=0.9390
# Epoch 71/100: Train Loss=0.0315, Val Loss=0.2405, Val Acc=0.9380
# Epoch 72/100: Train Loss=0.0326, Val Loss=0.2442, Val Acc=0.9380
# Epoch 73/100: Train Loss=0.0280, Val Loss=0.2482, Val Acc=0.9390
# Epoch 74/100: Train Loss=0.0438, Val Loss=0.2517, Val Acc=0.9390
# Epoch 75/100: Train Loss=0.0437, Val Loss=0.2502, Val Acc=0.9360
# Epoch 76/100: Train Loss=0.0434, Val Loss=0.2442, Val Acc=0.9350
# Epoch 77/100: Train Loss=0.0354, Val Loss=0.2327, Val Acc=0.9400
# Epoch 78/100: Train Loss=0.0379, Val Loss=0.2454, Val Acc=0.9350
# Epoch 79/100: Train Loss=0.0352, Val Loss=0.2423, Val Acc=0.9320
# Epoch 80/100: Train Loss=0.0484, Val Loss=0.2521, Val Acc=0.9370
# Epoch 81/100: Train Loss=0.0330, Val Loss=0.2567, Val Acc=0.9350
# Epoch 82/100: Train Loss=0.0410, Val Loss=0.2494, Val Acc=0.9360
# Epoch 83/100: Train Loss=0.0315, Val Loss=0.2498, Val Acc=0.9340
# Epoch 84/100: Train Loss=0.0231, Val Loss=0.2469, Val Acc=0.9340
# Epoch 85/100: Train Loss=0.0343, Val Loss=0.2465, Val Acc=0.9360
# Epoch 86/100: Train Loss=0.0352, Val Loss=0.2393, Val Acc=0.9410
# Epoch 87/100: Train Loss=0.0292, Val Loss=0.2423, Val Acc=0.9390
# Epoch 88/100: Train Loss=0.0262, Val Loss=0.2454, Val Acc=0.9340
# Epoch 89/100: Train Loss=0.0360, Val Loss=0.2473, Val Acc=0.9370
# Epoch 90/100: Train Loss=0.0263, Val Loss=0.2480, Val Acc=0.9380
# Epoch 91/100: Train Loss=0.0247, Val Loss=0.2476, Val Acc=0.9360
# Epoch 92/100: Train Loss=0.0317, Val Loss=0.2492, Val Acc=0.9380
# Epoch 93/100: Train Loss=0.0257, Val Loss=0.2439, Val Acc=0.9400
# Epoch 94/100: Train Loss=0.0323, Val Loss=0.2474, Val Acc=0.9350
# Epoch 95/100: Train Loss=0.0320, Val Loss=0.2535, Val Acc=0.9370
# Epoch 96/100: Train Loss=0.0331, Val Loss=0.2632, Val Acc=0.9370
# Epoch 97/100: Train Loss=0.0375, Val Loss=0.2633, Val Acc=0.9350
# Epoch 98/100: Train Loss=0.0343, Val Loss=0.2522, Val Acc=0.9340
# Epoch 99/100: Train Loss=0.0247, Val Loss=0.2439, Val Acc=0.9390
# Epoch 100/100: Train Loss=0.0204, Val Loss=0.2438, Val Acc=0.9380
# WD=0.0001 -> Val Loss: 0.2170
#
# Running Experiment 2 with weight decay = 0.001
# Epoch 1/100: Train Loss=2.4959, Val Loss=1.6715, Val Acc=0.4450
# Epoch 2/100: Train Loss=1.2326, Val Loss=0.7765, Val Acc=0.7490
# Epoch 3/100: Train Loss=0.6404, Val Loss=0.4402, Val Acc=0.8530
# Epoch 4/100: Train Loss=0.4075, Val Loss=0.3496, Val Acc=0.8840
# Epoch 5/100: Train Loss=0.2912, Val Loss=0.3111, Val Acc=0.9070
# Epoch 6/100: Train Loss=0.2799, Val Loss=0.2840, Val Acc=0.9240
# Epoch 7/100: Train Loss=0.2304, Val Loss=0.2650, Val Acc=0.9230
# Epoch 8/100: Train Loss=0.2210, Val Loss=0.2488, Val Acc=0.9280
# Epoch 9/100: Train Loss=0.1598, Val Loss=0.2552, Val Acc=0.9270
# Epoch 10/100: Train Loss=0.1836, Val Loss=0.2461, Val Acc=0.9250
# Epoch 11/100: Train Loss=0.1592, Val Loss=0.2464, Val Acc=0.9270
# Epoch 12/100: Train Loss=0.1910, Val Loss=0.2363, Val Acc=0.9310
# Epoch 13/100: Train Loss=0.1735, Val Loss=0.2455, Val Acc=0.9250
# Epoch 14/100: Train Loss=0.1547, Val Loss=0.2290, Val Acc=0.9260
# Epoch 15/100: Train Loss=0.1264, Val Loss=0.2246, Val Acc=0.9340
# Epoch 16/100: Train Loss=0.1549, Val Loss=0.2343, Val Acc=0.9270
# Epoch 17/100: Train Loss=0.1600, Val Loss=0.2364, Val Acc=0.9270
# Epoch 18/100: Train Loss=0.1318, Val Loss=0.2423, Val Acc=0.9280
# Epoch 19/100: Train Loss=0.1408, Val Loss=0.2388, Val Acc=0.9260
# Epoch 20/100: Train Loss=0.1158, Val Loss=0.2320, Val Acc=0.9350
# Epoch 21/100: Train Loss=0.1649, Val Loss=0.2390, Val Acc=0.9290
# Epoch 22/100: Train Loss=0.1627, Val Loss=0.2351, Val Acc=0.9280
# Epoch 23/100: Train Loss=0.1557, Val Loss=0.2271, Val Acc=0.9260
# Epoch 24/100: Train Loss=0.1608, Val Loss=0.2494, Val Acc=0.9180
# Epoch 25/100: Train Loss=0.1337, Val Loss=0.2680, Val Acc=0.9250
# Epoch 26/100: Train Loss=0.1517, Val Loss=0.2744, Val Acc=0.9110
# Epoch 27/100: Train Loss=0.1539, Val Loss=0.2453, Val Acc=0.9280
# Epoch 28/100: Train Loss=0.1425, Val Loss=0.2591, Val Acc=0.9230
# Epoch 29/100: Train Loss=0.1462, Val Loss=0.2389, Val Acc=0.9310
# Epoch 30/100: Train Loss=0.1351, Val Loss=0.2361, Val Acc=0.9320
# Epoch 31/100: Train Loss=0.1396, Val Loss=0.2363, Val Acc=0.9300
# Epoch 32/100: Train Loss=0.1209, Val Loss=0.2218, Val Acc=0.9300
# Epoch 33/100: Train Loss=0.1337, Val Loss=0.2490, Val Acc=0.9330
# Epoch 34/100: Train Loss=0.1450, Val Loss=0.2437, Val Acc=0.9340
# Epoch 35/100: Train Loss=0.1420, Val Loss=0.2440, Val Acc=0.9310
# Epoch 36/100: Train Loss=0.1119, Val Loss=0.2463, Val Acc=0.9260
# Epoch 37/100: Train Loss=0.1226, Val Loss=0.2391, Val Acc=0.9350
# Epoch 38/100: Train Loss=0.1266, Val Loss=0.2310, Val Acc=0.9310
# Epoch 39/100: Train Loss=0.1096, Val Loss=0.2218, Val Acc=0.9310
# Epoch 40/100: Train Loss=0.1305, Val Loss=0.2326, Val Acc=0.9280
# Epoch 41/100: Train Loss=0.1220, Val Loss=0.2561, Val Acc=0.9240
# Epoch 42/100: Train Loss=0.1274, Val Loss=0.2413, Val Acc=0.9300
# Epoch 43/100: Train Loss=0.1590, Val Loss=0.2370, Val Acc=0.9330
# Epoch 44/100: Train Loss=0.1386, Val Loss=0.2446, Val Acc=0.9270
# Epoch 45/100: Train Loss=0.1238, Val Loss=0.2415, Val Acc=0.9260
# Epoch 46/100: Train Loss=0.1263, Val Loss=0.2225, Val Acc=0.9290
# Epoch 47/100: Train Loss=0.1229, Val Loss=0.2255, Val Acc=0.9340
# Epoch 48/100: Train Loss=0.1300, Val Loss=0.2396, Val Acc=0.9290
# Epoch 49/100: Train Loss=0.1182, Val Loss=0.2528, Val Acc=0.9140
# Epoch 50/100: Train Loss=0.1332, Val Loss=0.2267, Val Acc=0.9300
# Epoch 51/100: Train Loss=0.1225, Val Loss=0.2315, Val Acc=0.9350
# Epoch 52/100: Train Loss=0.1223, Val Loss=0.2408, Val Acc=0.9280
# Epoch 53/100: Train Loss=0.1259, Val Loss=0.2194, Val Acc=0.9400
# Epoch 54/100: Train Loss=0.1212, Val Loss=0.2404, Val Acc=0.9310
# Epoch 55/100: Train Loss=0.1225, Val Loss=0.2360, Val Acc=0.9280
# Epoch 56/100: Train Loss=0.1285, Val Loss=0.2480, Val Acc=0.9230
# Epoch 57/100: Train Loss=0.1145, Val Loss=0.2494, Val Acc=0.9260
# Epoch 58/100: Train Loss=0.1294, Val Loss=0.2283, Val Acc=0.9300
# Epoch 59/100: Train Loss=0.1301, Val Loss=0.2451, Val Acc=0.9220
# Epoch 60/100: Train Loss=0.1208, Val Loss=0.2354, Val Acc=0.9280
# Epoch 61/100: Train Loss=0.1228, Val Loss=0.2220, Val Acc=0.9360
# Epoch 62/100: Train Loss=0.1343, Val Loss=0.2521, Val Acc=0.9240
# Epoch 63/100: Train Loss=0.1363, Val Loss=0.2370, Val Acc=0.9300
# Epoch 64/100: Train Loss=0.1183, Val Loss=0.2265, Val Acc=0.9340
# Epoch 65/100: Train Loss=0.1201, Val Loss=0.2451, Val Acc=0.9300
# Epoch 66/100: Train Loss=0.1320, Val Loss=0.2341, Val Acc=0.9330
# Epoch 67/100: Train Loss=0.1143, Val Loss=0.2334, Val Acc=0.9330
# Epoch 68/100: Train Loss=0.1306, Val Loss=0.2220, Val Acc=0.9310
# Epoch 69/100: Train Loss=0.1131, Val Loss=0.2607, Val Acc=0.9240
# Epoch 70/100: Train Loss=0.1354, Val Loss=0.2283, Val Acc=0.9300
# Epoch 71/100: Train Loss=0.1314, Val Loss=0.2322, Val Acc=0.9300
# Epoch 72/100: Train Loss=0.1166, Val Loss=0.2304, Val Acc=0.9330
# Epoch 73/100: Train Loss=0.1256, Val Loss=0.2324, Val Acc=0.9320
# Epoch 74/100: Train Loss=0.1012, Val Loss=0.2362, Val Acc=0.9310
# Epoch 75/100: Train Loss=0.1055, Val Loss=0.2419, Val Acc=0.9330
# Epoch 76/100: Train Loss=0.1291, Val Loss=0.2453, Val Acc=0.9280
# Epoch 77/100: Train Loss=0.1352, Val Loss=0.2707, Val Acc=0.9200
# Epoch 78/100: Train Loss=0.1270, Val Loss=0.2426, Val Acc=0.9240
# Epoch 79/100: Train Loss=0.1358, Val Loss=0.2485, Val Acc=0.9250
# Epoch 80/100: Train Loss=0.1140, Val Loss=0.2234, Val Acc=0.9330
# Epoch 81/100: Train Loss=0.1122, Val Loss=0.2257, Val Acc=0.9310
# Epoch 82/100: Train Loss=0.1269, Val Loss=0.2367, Val Acc=0.9320
# Epoch 83/100: Train Loss=0.1306, Val Loss=0.2177, Val Acc=0.9360
# Epoch 84/100: Train Loss=0.1080, Val Loss=0.2248, Val Acc=0.9340
# Epoch 85/100: Train Loss=0.1067, Val Loss=0.2220, Val Acc=0.9340
# Epoch 86/100: Train Loss=0.1359, Val Loss=0.2360, Val Acc=0.9300
# Epoch 87/100: Train Loss=0.1119, Val Loss=0.2454, Val Acc=0.9310
# Epoch 88/100: Train Loss=0.1171, Val Loss=0.2416, Val Acc=0.9250
# Epoch 89/100: Train Loss=0.1227, Val Loss=0.2476, Val Acc=0.9270
# Epoch 90/100: Train Loss=0.1259, Val Loss=0.2312, Val Acc=0.9300
# Epoch 91/100: Train Loss=0.1081, Val Loss=0.2316, Val Acc=0.9320
# Epoch 92/100: Train Loss=0.1204, Val Loss=0.2421, Val Acc=0.9290
# Epoch 93/100: Train Loss=0.1051, Val Loss=0.2352, Val Acc=0.9270
# Epoch 94/100: Train Loss=0.1264, Val Loss=0.2437, Val Acc=0.9230
# Epoch 95/100: Train Loss=0.1227, Val Loss=0.2340, Val Acc=0.9260
# Epoch 96/100: Train Loss=0.1115, Val Loss=0.2253, Val Acc=0.9340
# Epoch 97/100: Train Loss=0.1182, Val Loss=0.2303, Val Acc=0.9270
# Epoch 98/100: Train Loss=0.1380, Val Loss=0.2453, Val Acc=0.9240
# Epoch 99/100: Train Loss=0.1118, Val Loss=0.2238, Val Acc=0.9300
# Epoch 100/100: Train Loss=0.1112, Val Loss=0.2417, Val Acc=0.9350
# WD=0.001 -> Val Loss: 0.2177
#
# Running Experiment 2 with weight decay = 0.01
# Epoch 1/100: Train Loss=2.9781, Val Loss=2.2748, Val Acc=0.0850
# Epoch 2/100: Train Loss=1.6429, Val Loss=1.2214, Val Acc=0.5510
# Epoch 3/100: Train Loss=1.0050, Val Loss=0.7181, Val Acc=0.7870
# Epoch 4/100: Train Loss=0.6963, Val Loss=0.6268, Val Acc=0.7960
# Epoch 5/100: Train Loss=0.6424, Val Loss=0.5715, Val Acc=0.8400
# Epoch 6/100: Train Loss=0.7178, Val Loss=0.5505, Val Acc=0.8710
# Epoch 7/100: Train Loss=0.6674, Val Loss=0.5712, Val Acc=0.8440
# Epoch 8/100: Train Loss=0.6030, Val Loss=0.5302, Val Acc=0.8670
# Epoch 9/100: Train Loss=0.5569, Val Loss=0.5157, Val Acc=0.8790
# Epoch 10/100: Train Loss=0.6320, Val Loss=0.5429, Val Acc=0.8490
# Epoch 11/100: Train Loss=0.5790, Val Loss=0.4942, Val Acc=0.8880
# Epoch 12/100: Train Loss=0.5619, Val Loss=0.4708, Val Acc=0.8960
# Epoch 13/100: Train Loss=0.6058, Val Loss=0.4841, Val Acc=0.8900
# Epoch 14/100: Train Loss=0.5755, Val Loss=0.5415, Val Acc=0.8520
# Epoch 15/100: Train Loss=0.5719, Val Loss=0.5640, Val Acc=0.8280
# Epoch 16/100: Train Loss=0.5706, Val Loss=0.4726, Val Acc=0.8750
# Epoch 17/100: Train Loss=0.5830, Val Loss=0.4906, Val Acc=0.8670
# Epoch 18/100: Train Loss=0.6192, Val Loss=0.5083, Val Acc=0.8800
# Epoch 19/100: Train Loss=0.5685, Val Loss=0.5507, Val Acc=0.8730
# Epoch 20/100: Train Loss=0.6043, Val Loss=0.5384, Val Acc=0.8480
# Epoch 21/100: Train Loss=0.6178, Val Loss=0.6090, Val Acc=0.8240
# Epoch 22/100: Train Loss=0.6224, Val Loss=0.5127, Val Acc=0.8580
# Epoch 23/100: Train Loss=0.6105, Val Loss=0.5604, Val Acc=0.8360
# Epoch 24/100: Train Loss=0.5736, Val Loss=0.5266, Val Acc=0.8590
# Epoch 25/100: Train Loss=0.5662, Val Loss=0.5014, Val Acc=0.8620
# Epoch 26/100: Train Loss=0.5822, Val Loss=0.4944, Val Acc=0.8710
# Epoch 27/100: Train Loss=0.5572, Val Loss=0.5407, Val Acc=0.8430
# Epoch 28/100: Train Loss=0.6278, Val Loss=0.5485, Val Acc=0.8390
# Epoch 29/100: Train Loss=0.5969, Val Loss=0.4955, Val Acc=0.8860
# Epoch 30/100: Train Loss=0.6236, Val Loss=0.5103, Val Acc=0.8600
# Epoch 31/100: Train Loss=0.5813, Val Loss=0.4997, Val Acc=0.8590
# Epoch 32/100: Train Loss=0.5655, Val Loss=0.5920, Val Acc=0.8210
# Epoch 33/100: Train Loss=0.6348, Val Loss=0.5543, Val Acc=0.8560
# Epoch 34/100: Train Loss=0.5860, Val Loss=0.5563, Val Acc=0.8500
# Epoch 35/100: Train Loss=0.5920, Val Loss=0.4803, Val Acc=0.8810
# Epoch 36/100: Train Loss=0.5902, Val Loss=0.5106, Val Acc=0.8640
# Epoch 37/100: Train Loss=0.5789, Val Loss=0.5049, Val Acc=0.8740
# Epoch 38/100: Train Loss=0.5874, Val Loss=0.5556, Val Acc=0.8370
# Epoch 39/100: Train Loss=0.5756, Val Loss=0.5278, Val Acc=0.8500
# Epoch 40/100: Train Loss=0.6319, Val Loss=0.5781, Val Acc=0.8380
# Epoch 41/100: Train Loss=0.6187, Val Loss=0.5609, Val Acc=0.8290
# Epoch 42/100: Train Loss=0.5791, Val Loss=0.6065, Val Acc=0.7820
# Epoch 43/100: Train Loss=0.6270, Val Loss=0.5699, Val Acc=0.8420
# Epoch 44/100: Train Loss=0.6719, Val Loss=0.5640, Val Acc=0.8450
# Epoch 45/100: Train Loss=0.5933, Val Loss=0.4845, Val Acc=0.8820
# Epoch 46/100: Train Loss=0.5821, Val Loss=0.5981, Val Acc=0.8070
# Epoch 47/100: Train Loss=0.6150, Val Loss=0.6265, Val Acc=0.7860
# Epoch 48/100: Train Loss=0.6265, Val Loss=0.5275, Val Acc=0.8610
# Epoch 49/100: Train Loss=0.5926, Val Loss=0.5291, Val Acc=0.8550
# Epoch 50/100: Train Loss=0.6452, Val Loss=0.5721, Val Acc=0.8370
# Epoch 51/100: Train Loss=0.6228, Val Loss=0.5371, Val Acc=0.8590
# Epoch 52/100: Train Loss=0.5839, Val Loss=0.4768, Val Acc=0.8810
# Epoch 53/100: Train Loss=0.5905, Val Loss=0.5017, Val Acc=0.8850
# Epoch 54/100: Train Loss=0.5844, Val Loss=0.5409, Val Acc=0.8450
# Epoch 55/100: Train Loss=0.5921, Val Loss=0.5428, Val Acc=0.8400
# Epoch 56/100: Train Loss=0.5674, Val Loss=0.4870, Val Acc=0.8890
# Epoch 57/100: Train Loss=0.5799, Val Loss=0.5434, Val Acc=0.8370
# Epoch 58/100: Train Loss=0.6010, Val Loss=0.5399, Val Acc=0.8650
# Epoch 59/100: Train Loss=0.6022, Val Loss=0.5365, Val Acc=0.8490
# Epoch 60/100: Train Loss=0.6235, Val Loss=0.4745, Val Acc=0.8830
# Epoch 61/100: Train Loss=0.5591, Val Loss=0.6206, Val Acc=0.7930
# Epoch 62/100: Train Loss=0.6421, Val Loss=0.5433, Val Acc=0.8440
# Epoch 63/100: Train Loss=0.6070, Val Loss=0.4473, Val Acc=0.8920
# Epoch 64/100: Train Loss=0.5365, Val Loss=0.4782, Val Acc=0.8770
# Epoch 65/100: Train Loss=0.5881, Val Loss=0.5305, Val Acc=0.8480
# Epoch 66/100: Train Loss=0.5913, Val Loss=0.5490, Val Acc=0.8530
# Epoch 67/100: Train Loss=0.5618, Val Loss=0.4830, Val Acc=0.8770
# Epoch 68/100: Train Loss=0.5725, Val Loss=0.5611, Val Acc=0.8390
# Epoch 69/100: Train Loss=0.5907, Val Loss=0.4550, Val Acc=0.9140
# Epoch 70/100: Train Loss=0.5759, Val Loss=0.5748, Val Acc=0.8390
# Epoch 71/100: Train Loss=0.6160, Val Loss=0.5671, Val Acc=0.8370
# Epoch 72/100: Train Loss=0.5679, Val Loss=0.5136, Val Acc=0.8710
# Epoch 73/100: Train Loss=0.5797, Val Loss=0.4593, Val Acc=0.8980
# Epoch 74/100: Train Loss=0.6192, Val Loss=0.5343, Val Acc=0.8690
# Epoch 75/100: Train Loss=0.5732, Val Loss=0.4900, Val Acc=0.8810
# Epoch 76/100: Train Loss=0.5718, Val Loss=0.4980, Val Acc=0.8720
# Epoch 77/100: Train Loss=0.5943, Val Loss=0.5017, Val Acc=0.8640
# Epoch 78/100: Train Loss=0.5509, Val Loss=0.4847, Val Acc=0.8920
# Epoch 79/100: Train Loss=0.5867, Val Loss=0.4676, Val Acc=0.8840
# Epoch 80/100: Train Loss=0.5579, Val Loss=0.4967, Val Acc=0.8710
# Epoch 81/100: Train Loss=0.6099, Val Loss=0.5184, Val Acc=0.8580
# Epoch 82/100: Train Loss=0.5493, Val Loss=0.5001, Val Acc=0.8540
# Epoch 83/100: Train Loss=0.5782, Val Loss=0.5260, Val Acc=0.8750
# Epoch 84/100: Train Loss=0.5955, Val Loss=0.5351, Val Acc=0.8660
# Epoch 85/100: Train Loss=0.6149, Val Loss=0.5219, Val Acc=0.8540
# Epoch 86/100: Train Loss=0.6015, Val Loss=0.5559, Val Acc=0.8260
# Epoch 87/100: Train Loss=0.5721, Val Loss=0.5532, Val Acc=0.8360
# Epoch 88/100: Train Loss=0.5903, Val Loss=0.5100, Val Acc=0.8630
# Epoch 89/100: Train Loss=0.5767, Val Loss=0.5066, Val Acc=0.8830
# Epoch 90/100: Train Loss=0.6320, Val Loss=0.5534, Val Acc=0.8540
# Epoch 91/100: Train Loss=0.6384, Val Loss=0.6302, Val Acc=0.7780
# Epoch 92/100: Train Loss=0.6568, Val Loss=0.6997, Val Acc=0.7540
# Epoch 93/100: Train Loss=0.6351, Val Loss=0.6244, Val Acc=0.7830
# Epoch 94/100: Train Loss=0.6131, Val Loss=0.5319, Val Acc=0.8410
# Epoch 95/100: Train Loss=0.5984, Val Loss=0.5283, Val Acc=0.8390
# Epoch 96/100: Train Loss=0.5643, Val Loss=0.5580, Val Acc=0.8300
# Epoch 97/100: Train Loss=0.6390, Val Loss=0.5742, Val Acc=0.8600
# Epoch 98/100: Train Loss=0.6001, Val Loss=0.5464, Val Acc=0.8830
# Epoch 99/100: Train Loss=0.5724, Val Loss=0.4694, Val Acc=0.8900
# Epoch 100/100: Train Loss=0.5816, Val Loss=0.4949, Val Acc=0.8970
# WD=0.01 -> Val Loss: 0.4473
#
# Running Experiment 2 with weight decay = 1
# Epoch 1/100: Train Loss=4.2653, Val Loss=4.4560, Val Acc=0.1770
# Epoch 2/100: Train Loss=5.4442, Val Loss=4.2247, Val Acc=0.1000
# Epoch 3/100: Train Loss=5.1847, Val Loss=5.4656, Val Acc=0.1770
# Epoch 4/100: Train Loss=5.4711, Val Loss=6.1283, Val Acc=0.1770
# Epoch 5/100: Train Loss=5.3546, Val Loss=6.1596, Val Acc=0.0750
# Epoch 6/100: Train Loss=6.8092, Val Loss=10.0960, Val Acc=0.0960
# Epoch 7/100: Train Loss=7.7140, Val Loss=7.5550, Val Acc=0.1770
# Epoch 8/100: Train Loss=7.2973, Val Loss=6.6754, Val Acc=0.0870
# Epoch 9/100: Train Loss=6.8570, Val Loss=8.1525, Val Acc=0.0780
# Epoch 10/100: Train Loss=6.3120, Val Loss=4.1860, Val Acc=0.0850
# Epoch 11/100: Train Loss=5.4240, Val Loss=5.2379, Val Acc=0.0860
# Epoch 12/100: Train Loss=7.0158, Val Loss=6.2021, Val Acc=0.1770
# Epoch 13/100: Train Loss=6.1418, Val Loss=5.1542, Val Acc=0.1770
# Epoch 14/100: Train Loss=5.7710, Val Loss=5.7596, Val Acc=0.0750
# Epoch 15/100: Train Loss=7.6157, Val Loss=5.7717, Val Acc=0.0960
# Epoch 16/100: Train Loss=6.5320, Val Loss=8.5482, Val Acc=0.1340
# Epoch 17/100: Train Loss=7.8120, Val Loss=7.9480, Val Acc=0.0850
# Epoch 18/100: Train Loss=7.0915, Val Loss=8.3967, Val Acc=0.0960
# Epoch 19/100: Train Loss=6.5776, Val Loss=7.0425, Val Acc=0.1770
# Epoch 20/100: Train Loss=6.7355, Val Loss=7.7987, Val Acc=0.0850
# Epoch 21/100: Train Loss=6.9546, Val Loss=6.9614, Val Acc=0.0960
# Epoch 22/100: Train Loss=7.6973, Val Loss=5.2789, Val Acc=0.0770
# Epoch 23/100: Train Loss=7.1686, Val Loss=6.6831, Val Acc=0.0870
# Epoch 24/100: Train Loss=7.7495, Val Loss=7.6604, Val Acc=0.0960
# Epoch 25/100: Train Loss=7.5366, Val Loss=5.7225, Val Acc=0.0650
# Epoch 26/100: Train Loss=7.4388, Val Loss=5.9085, Val Acc=0.0850
# Epoch 27/100: Train Loss=7.0165, Val Loss=7.8310, Val Acc=0.0960
# Epoch 28/100: Train Loss=7.1421, Val Loss=7.3347, Val Acc=0.0870
# Epoch 29/100: Train Loss=7.6266, Val Loss=7.8018, Val Acc=0.0780
# Epoch 30/100: Train Loss=6.9614, Val Loss=8.8616, Val Acc=0.0870
# Epoch 31/100: Train Loss=6.5374, Val Loss=6.1250, Val Acc=0.1770
# Epoch 32/100: Train Loss=7.3939, Val Loss=5.0377, Val Acc=0.0960
# Epoch 33/100: Train Loss=6.9257, Val Loss=7.9615, Val Acc=0.0850
# Epoch 34/100: Train Loss=7.1153, Val Loss=9.2493, Val Acc=0.1770
# Epoch 35/100: Train Loss=7.2598, Val Loss=5.3165, Val Acc=0.1000
# Epoch 36/100: Train Loss=7.7828, Val Loss=5.1811, Val Acc=0.1340
# Epoch 37/100: Train Loss=6.5337, Val Loss=9.5803, Val Acc=0.1770
# Epoch 38/100: Train Loss=7.2682, Val Loss=7.2800, Val Acc=0.1000
# Epoch 39/100: Train Loss=7.5486, Val Loss=9.0148, Val Acc=0.0780
# Epoch 40/100: Train Loss=7.0470, Val Loss=4.4570, Val Acc=0.1770
# Epoch 41/100: Train Loss=6.4265, Val Loss=6.8047, Val Acc=0.0870
# Epoch 42/100: Train Loss=7.6233, Val Loss=5.9461, Val Acc=0.0910
# Epoch 43/100: Train Loss=6.9819, Val Loss=8.8127, Val Acc=0.1340
# Epoch 44/100: Train Loss=7.2118, Val Loss=5.8392, Val Acc=0.0870
# Epoch 45/100: Train Loss=7.5528, Val Loss=6.4509, Val Acc=0.0780
# Epoch 46/100: Train Loss=6.7052, Val Loss=8.9459, Val Acc=0.1340
# Epoch 47/100: Train Loss=7.2939, Val Loss=5.4856, Val Acc=0.0870
# Epoch 48/100: Train Loss=7.3256, Val Loss=7.1234, Val Acc=0.0960
# Epoch 49/100: Train Loss=6.6646, Val Loss=9.1272, Val Acc=0.1340
# Epoch 50/100: Train Loss=6.8749, Val Loss=5.0897, Val Acc=0.0870
# Epoch 51/100: Train Loss=6.9224, Val Loss=7.9123, Val Acc=0.0780
# Epoch 52/100: Train Loss=7.4354, Val Loss=7.1478, Val Acc=0.0910
# Epoch 53/100: Train Loss=6.6206, Val Loss=8.4387, Val Acc=0.1340
# Epoch 54/100: Train Loss=7.3167, Val Loss=4.9568, Val Acc=0.1140
# Epoch 55/100: Train Loss=7.0462, Val Loss=6.0010, Val Acc=0.0780
# Epoch 56/100: Train Loss=7.3830, Val Loss=7.2492, Val Acc=0.1340
# Epoch 57/100: Train Loss=7.6833, Val Loss=5.5438, Val Acc=0.1000
# Epoch 58/100: Train Loss=7.3273, Val Loss=6.0104, Val Acc=0.0780
# Epoch 59/100: Train Loss=7.2726, Val Loss=9.2868, Val Acc=0.1340
# Epoch 60/100: Train Loss=7.3236, Val Loss=5.0656, Val Acc=0.1000
# Epoch 61/100: Train Loss=7.5058, Val Loss=6.3634, Val Acc=0.0780
# Epoch 62/100: Train Loss=6.6938, Val Loss=9.2007, Val Acc=0.1340
# Epoch 63/100: Train Loss=7.3012, Val Loss=11.0991, Val Acc=0.0850
# Epoch 64/100: Train Loss=7.9407, Val Loss=4.6068, Val Acc=0.1770
# Epoch 65/100: Train Loss=6.9159, Val Loss=8.6960, Val Acc=0.0850
# Epoch 66/100: Train Loss=7.0043, Val Loss=5.2222, Val Acc=0.0960
# Epoch 67/100: Train Loss=6.6443, Val Loss=5.5633, Val Acc=0.0870
# Epoch 68/100: Train Loss=7.2286, Val Loss=8.4775, Val Acc=0.1770
# Epoch 69/100: Train Loss=7.3271, Val Loss=6.6198, Val Acc=0.0770
# Epoch 70/100: Train Loss=6.9335, Val Loss=7.1753, Val Acc=0.1000
# Epoch 71/100: Train Loss=6.8305, Val Loss=8.9596, Val Acc=0.1770
# Epoch 72/100: Train Loss=6.6534, Val Loss=7.9860, Val Acc=0.0750
# Epoch 73/100: Train Loss=6.5128, Val Loss=8.4905, Val Acc=0.0850
# Epoch 74/100: Train Loss=6.6858, Val Loss=5.0279, Val Acc=0.0960
# Epoch 75/100: Train Loss=6.4730, Val Loss=6.1049, Val Acc=0.1340
# Epoch 76/100: Train Loss=6.2756, Val Loss=8.2033, Val Acc=0.0770
# Epoch 77/100: Train Loss=7.9305, Val Loss=4.5251, Val Acc=0.0850
# Epoch 78/100: Train Loss=6.6528, Val Loss=8.8691, Val Acc=0.1340
# Epoch 79/100: Train Loss=7.7112, Val Loss=5.7521, Val Acc=0.0870
# Epoch 80/100: Train Loss=7.2838, Val Loss=8.2654, Val Acc=0.0850
# Epoch 81/100: Train Loss=6.7398, Val Loss=7.5354, Val Acc=0.1770
# Epoch 82/100: Train Loss=7.1921, Val Loss=7.0168, Val Acc=0.1340
# Epoch 83/100: Train Loss=7.5929, Val Loss=5.7512, Val Acc=0.0870
# Epoch 84/100: Train Loss=6.9936, Val Loss=9.1255, Val Acc=0.1770
# Epoch 85/100: Train Loss=6.5410, Val Loss=7.1009, Val Acc=0.0850
# Epoch 86/100: Train Loss=7.1708, Val Loss=5.7239, Val Acc=0.0750
# Epoch 87/100: Train Loss=6.9846, Val Loss=6.6137, Val Acc=0.1770
# Epoch 88/100: Train Loss=7.4520, Val Loss=7.5388, Val Acc=0.0850
# Epoch 89/100: Train Loss=6.8887, Val Loss=8.1050, Val Acc=0.1000
# Epoch 90/100: Train Loss=7.7016, Val Loss=5.6077, Val Acc=0.1770
# Epoch 91/100: Train Loss=6.8751, Val Loss=5.7879, Val Acc=0.0780
# Epoch 92/100: Train Loss=7.2676, Val Loss=9.7842, Val Acc=0.0960
# Epoch 93/100: Train Loss=6.8250, Val Loss=5.1636, Val Acc=0.1340
# Epoch 94/100: Train Loss=7.0234, Val Loss=8.6420, Val Acc=0.1000
# Epoch 95/100: Train Loss=6.2395, Val Loss=6.5857, Val Acc=0.0960
# Epoch 96/100: Train Loss=6.9921, Val Loss=5.5246, Val Acc=0.0850
# Epoch 97/100: Train Loss=6.9634, Val Loss=6.4030, Val Acc=0.1340
# Epoch 98/100: Train Loss=7.2427, Val Loss=7.5431, Val Acc=0.0960
# Epoch 99/100: Train Loss=6.1939, Val Loss=7.2932, Val Acc=0.0850
# Epoch 100/100: Train Loss=7.2922, Val Loss=7.0473, Val Acc=0.0870
# WD=1 -> Val Loss: 4.1860
#
# Running Experiment 2 with weight decay = 2
# Epoch 1/100: Train Loss=3.7721, Val Loss=4.6607, Val Acc=0.1770
# Epoch 2/100: Train Loss=7.1329, Val Loss=8.2892, Val Acc=0.1340
# Epoch 3/100: Train Loss=6.8465, Val Loss=9.2737, Val Acc=0.1340
# Epoch 4/100: Train Loss=9.9262, Val Loss=9.2509, Val Acc=0.1340
# Epoch 5/100: Train Loss=11.3529, Val Loss=4.7611, Val Acc=0.1340
# Epoch 6/100: Train Loss=10.7498, Val Loss=6.2464, Val Acc=0.0780
# Epoch 7/100: Train Loss=10.2177, Val Loss=13.0692, Val Acc=0.0780
# Epoch 8/100: Train Loss=11.9236, Val Loss=10.8115, Val Acc=0.0780
# Epoch 9/100: Train Loss=11.6437, Val Loss=10.9667, Val Acc=0.0780
# Epoch 10/100: Train Loss=10.9492, Val Loss=11.9042, Val Acc=0.0780
# Epoch 11/100: Train Loss=11.1502, Val Loss=10.3926, Val Acc=0.0780
# Epoch 12/100: Train Loss=11.1065, Val Loss=8.6580, Val Acc=0.0780
# Epoch 13/100: Train Loss=11.2696, Val Loss=13.2731, Val Acc=0.0780
# Epoch 14/100: Train Loss=11.1561, Val Loss=11.5366, Val Acc=0.0780
# Epoch 15/100: Train Loss=11.2463, Val Loss=10.8186, Val Acc=0.0780
# Epoch 16/100: Train Loss=10.9943, Val Loss=12.1432, Val Acc=0.0780
# Epoch 17/100: Train Loss=11.3183, Val Loss=11.8236, Val Acc=0.0780
# Epoch 18/100: Train Loss=11.5217, Val Loss=13.2768, Val Acc=0.0780
# Epoch 19/100: Train Loss=11.2281, Val Loss=11.5643, Val Acc=0.0780
# Epoch 20/100: Train Loss=10.8187, Val Loss=11.3349, Val Acc=0.0780
# Epoch 21/100: Train Loss=11.2651, Val Loss=11.6711, Val Acc=0.0780
# Epoch 22/100: Train Loss=11.0524, Val Loss=10.0160, Val Acc=0.0780
# Epoch 23/100: Train Loss=10.5698, Val Loss=10.4975, Val Acc=0.0780
# Epoch 24/100: Train Loss=10.3183, Val Loss=11.7469, Val Acc=0.0780
# Epoch 25/100: Train Loss=11.0942, Val Loss=13.2576, Val Acc=0.0780
# Epoch 26/100: Train Loss=10.7471, Val Loss=10.3518, Val Acc=0.0780
# Epoch 27/100: Train Loss=10.6293, Val Loss=11.4904, Val Acc=0.0780
# Epoch 28/100: Train Loss=10.6562, Val Loss=10.8861, Val Acc=0.0780
# Epoch 29/100: Train Loss=10.6085, Val Loss=9.4006, Val Acc=0.0780
# Epoch 30/100: Train Loss=10.8143, Val Loss=9.5122, Val Acc=0.0780
# Epoch 31/100: Train Loss=11.0141, Val Loss=9.7052, Val Acc=0.0780
# Epoch 32/100: Train Loss=11.4397, Val Loss=10.1803, Val Acc=0.0780
# Epoch 33/100: Train Loss=11.3576, Val Loss=10.7606, Val Acc=0.0780
# Epoch 34/100: Train Loss=10.5163, Val Loss=11.0086, Val Acc=0.0780
# Epoch 35/100: Train Loss=11.2793, Val Loss=8.8140, Val Acc=0.0780
# Epoch 36/100: Train Loss=11.1826, Val Loss=11.7148, Val Acc=0.0780
# Epoch 37/100: Train Loss=11.2195, Val Loss=10.2504, Val Acc=0.0780
# Epoch 38/100: Train Loss=10.7998, Val Loss=11.4099, Val Acc=0.0780
# Epoch 39/100: Train Loss=10.8922, Val Loss=7.5718, Val Acc=0.0780
# Epoch 40/100: Train Loss=10.7033, Val Loss=12.3391, Val Acc=0.0780
# Epoch 41/100: Train Loss=11.3600, Val Loss=11.0702, Val Acc=0.0780
# Epoch 42/100: Train Loss=11.1248, Val Loss=8.9012, Val Acc=0.0780
# Epoch 43/100: Train Loss=11.1650, Val Loss=11.0385, Val Acc=0.0780
# Epoch 44/100: Train Loss=10.6525, Val Loss=10.2066, Val Acc=0.0780
# Epoch 45/100: Train Loss=11.1620, Val Loss=11.1276, Val Acc=0.0780
# Epoch 46/100: Train Loss=11.0437, Val Loss=8.3090, Val Acc=0.0780
# Epoch 47/100: Train Loss=11.4168, Val Loss=9.4519, Val Acc=0.0780
# Epoch 48/100: Train Loss=10.8977, Val Loss=9.0983, Val Acc=0.0780
# Epoch 49/100: Train Loss=10.9933, Val Loss=10.0772, Val Acc=0.0780
# Epoch 50/100: Train Loss=11.0795, Val Loss=9.6246, Val Acc=0.0780
# Epoch 51/100: Train Loss=11.9053, Val Loss=8.2801, Val Acc=0.0780
# Epoch 52/100: Train Loss=11.1688, Val Loss=9.5073, Val Acc=0.0780
# Epoch 53/100: Train Loss=10.8588, Val Loss=10.7117, Val Acc=0.0780
# Epoch 54/100: Train Loss=11.9365, Val Loss=11.2785, Val Acc=0.0780
# Epoch 55/100: Train Loss=11.2347, Val Loss=10.2926, Val Acc=0.0780
# Epoch 56/100: Train Loss=11.1928, Val Loss=10.9378, Val Acc=0.0780
# Epoch 57/100: Train Loss=11.4666, Val Loss=9.3310, Val Acc=0.0780
# Epoch 58/100: Train Loss=11.1419, Val Loss=9.6491, Val Acc=0.0780
# Epoch 59/100: Train Loss=11.5960, Val Loss=9.4870, Val Acc=0.0780
# Epoch 60/100: Train Loss=11.2115, Val Loss=10.5567, Val Acc=0.0780
# Epoch 61/100: Train Loss=10.7681, Val Loss=9.6106, Val Acc=0.0780
# Epoch 62/100: Train Loss=10.9715, Val Loss=9.8483, Val Acc=0.0780
# Epoch 63/100: Train Loss=10.9257, Val Loss=9.7155, Val Acc=0.0780
# Epoch 64/100: Train Loss=10.8944, Val Loss=9.4517, Val Acc=0.0780
# Epoch 65/100: Train Loss=10.5774, Val Loss=10.8786, Val Acc=0.0780
# Epoch 66/100: Train Loss=11.3622, Val Loss=10.4339, Val Acc=0.0780
# Epoch 67/100: Train Loss=11.4444, Val Loss=8.8558, Val Acc=0.0780
# Epoch 68/100: Train Loss=10.9205, Val Loss=9.7951, Val Acc=0.0780
# Epoch 69/100: Train Loss=11.7543, Val Loss=10.2894, Val Acc=0.0780
# Epoch 70/100: Train Loss=10.8156, Val Loss=12.2623, Val Acc=0.0780
# Epoch 71/100: Train Loss=10.9337, Val Loss=9.8912, Val Acc=0.0780
# Epoch 72/100: Train Loss=11.6990, Val Loss=8.8008, Val Acc=0.0780
# Epoch 73/100: Train Loss=10.7626, Val Loss=9.6056, Val Acc=0.0780
# Epoch 74/100: Train Loss=11.5992, Val Loss=10.2792, Val Acc=0.0780
# Epoch 75/100: Train Loss=11.0566, Val Loss=10.6622, Val Acc=0.0780
# Epoch 76/100: Train Loss=11.2340, Val Loss=10.4764, Val Acc=0.0780
# Epoch 77/100: Train Loss=11.0230, Val Loss=10.5002, Val Acc=0.0780
# Epoch 78/100: Train Loss=10.3840, Val Loss=9.0824, Val Acc=0.0780
# Epoch 79/100: Train Loss=11.4606, Val Loss=9.9018, Val Acc=0.0780
# Epoch 80/100: Train Loss=11.2337, Val Loss=9.1798, Val Acc=0.0780
# Epoch 81/100: Train Loss=11.1502, Val Loss=11.1373, Val Acc=0.0780
# Epoch 82/100: Train Loss=11.3462, Val Loss=9.6577, Val Acc=0.0780
# Epoch 83/100: Train Loss=11.6474, Val Loss=8.3607, Val Acc=0.0780
# Epoch 84/100: Train Loss=11.2998, Val Loss=12.6171, Val Acc=0.0780
# Epoch 85/100: Train Loss=10.6357, Val Loss=8.5278, Val Acc=0.0780
# Epoch 86/100: Train Loss=10.9028, Val Loss=9.9897, Val Acc=0.0780
# Epoch 87/100: Train Loss=11.5147, Val Loss=10.7898, Val Acc=0.0780
# Epoch 88/100: Train Loss=10.9128, Val Loss=9.2925, Val Acc=0.0780
# Epoch 89/100: Train Loss=10.9393, Val Loss=10.4511, Val Acc=0.0780
# Epoch 90/100: Train Loss=11.4769, Val Loss=7.4601, Val Acc=0.0780
# Epoch 91/100: Train Loss=10.6243, Val Loss=11.7804, Val Acc=0.0780
# Epoch 92/100: Train Loss=11.2371, Val Loss=10.9779, Val Acc=0.0780
# Epoch 93/100: Train Loss=10.7781, Val Loss=8.9375, Val Acc=0.0780
# Epoch 94/100: Train Loss=11.4808, Val Loss=9.1565, Val Acc=0.0780
# Epoch 95/100: Train Loss=10.5302, Val Loss=10.3032, Val Acc=0.0780
# Epoch 96/100: Train Loss=10.7568, Val Loss=10.9990, Val Acc=0.0780
# Epoch 97/100: Train Loss=11.2123, Val Loss=8.5517, Val Acc=0.0780
# Epoch 98/100: Train Loss=11.4132, Val Loss=9.2736, Val Acc=0.0780
# Epoch 99/100: Train Loss=10.7095, Val Loss=12.1244, Val Acc=0.0780
# Epoch 100/100: Train Loss=11.4227, Val Loss=10.4149, Val Acc=0.0780
# WD=2 -> Val Loss: 4.6607
#
# Running Experiment 2 with weight decay = 5
# Epoch 1/100: Train Loss=8.0849, Val Loss=18.9669, Val Acc=0.1770
# Epoch 2/100: Train Loss=12.5820, Val Loss=11.0164, Val Acc=0.1000
# Epoch 3/100: Train Loss=11.2480, Val Loss=10.5725, Val Acc=0.0960
# Epoch 4/100: Train Loss=12.3337, Val Loss=9.6110, Val Acc=0.1770
# Epoch 5/100: Train Loss=11.7613, Val Loss=12.7010, Val Acc=0.1000
# Epoch 6/100: Train Loss=11.7089, Val Loss=12.1161, Val Acc=0.0960
# Epoch 7/100: Train Loss=11.6982, Val Loss=9.2231, Val Acc=0.1770
# Epoch 8/100: Train Loss=12.1888, Val Loss=12.6720, Val Acc=0.1000
# Epoch 9/100: Train Loss=11.9348, Val Loss=13.7236, Val Acc=0.0960
# Epoch 10/100: Train Loss=12.0291, Val Loss=11.5671, Val Acc=0.1770
# Epoch 11/100: Train Loss=11.6868, Val Loss=12.7258, Val Acc=0.1000
# Epoch 12/100: Train Loss=12.2893, Val Loss=11.8529, Val Acc=0.0960
# Epoch 13/100: Train Loss=12.1106, Val Loss=10.5890, Val Acc=0.1770
# Epoch 14/100: Train Loss=11.4866, Val Loss=11.2915, Val Acc=0.1000
# Epoch 15/100: Train Loss=12.0058, Val Loss=9.4036, Val Acc=0.0960
# Epoch 16/100: Train Loss=12.2554, Val Loss=9.3956, Val Acc=0.1770
# Epoch 17/100: Train Loss=12.7078, Val Loss=12.4919, Val Acc=0.1000
# Epoch 18/100: Train Loss=11.1191, Val Loss=13.6346, Val Acc=0.0960
# Epoch 19/100: Train Loss=12.2144, Val Loss=11.7354, Val Acc=0.1770
# Epoch 20/100: Train Loss=11.9088, Val Loss=10.7279, Val Acc=0.1000
# Epoch 21/100: Train Loss=11.6882, Val Loss=11.8042, Val Acc=0.0960
# Epoch 22/100: Train Loss=11.9922, Val Loss=9.8815, Val Acc=0.1770
# Epoch 23/100: Train Loss=11.5858, Val Loss=12.3437, Val Acc=0.1000
# Epoch 24/100: Train Loss=11.8318, Val Loss=10.3914, Val Acc=0.0960
# Epoch 25/100: Train Loss=11.5232, Val Loss=11.9638, Val Acc=0.1770
# Epoch 26/100: Train Loss=11.7720, Val Loss=13.0739, Val Acc=0.1000
# Epoch 27/100: Train Loss=11.8878, Val Loss=14.8578, Val Acc=0.0960
# Epoch 28/100: Train Loss=11.8639, Val Loss=10.4904, Val Acc=0.1770
# Epoch 29/100: Train Loss=11.1902, Val Loss=13.2580, Val Acc=0.1000
# Epoch 30/100: Train Loss=12.0450, Val Loss=12.9916, Val Acc=0.0960
# Epoch 31/100: Train Loss=12.1979, Val Loss=11.6756, Val Acc=0.1770
# Epoch 32/100: Train Loss=11.8143, Val Loss=14.3139, Val Acc=0.1000
# Epoch 33/100: Train Loss=12.3496, Val Loss=12.9678, Val Acc=0.0960
# Epoch 34/100: Train Loss=11.8447, Val Loss=11.8933, Val Acc=0.1770
# Epoch 35/100: Train Loss=12.3150, Val Loss=14.0343, Val Acc=0.1000
# Epoch 36/100: Train Loss=11.2063, Val Loss=12.3144, Val Acc=0.0960
# Epoch 37/100: Train Loss=11.2332, Val Loss=10.8819, Val Acc=0.1770
# Epoch 38/100: Train Loss=12.2498, Val Loss=11.7865, Val Acc=0.1000
# Epoch 39/100: Train Loss=11.8913, Val Loss=13.1028, Val Acc=0.0960
# Epoch 40/100: Train Loss=11.7064, Val Loss=11.5042, Val Acc=0.1770
# Epoch 41/100: Train Loss=11.0869, Val Loss=13.8224, Val Acc=0.1000
# Epoch 42/100: Train Loss=12.0815, Val Loss=15.7167, Val Acc=0.0960
# Epoch 43/100: Train Loss=12.0917, Val Loss=12.8564, Val Acc=0.1770
# Epoch 44/100: Train Loss=11.4990, Val Loss=12.3879, Val Acc=0.1000
# Epoch 45/100: Train Loss=11.9303, Val Loss=13.2520, Val Acc=0.0960
# Epoch 46/100: Train Loss=12.5580, Val Loss=11.0105, Val Acc=0.1770
# Epoch 47/100: Train Loss=11.3417, Val Loss=12.3484, Val Acc=0.1000
# Epoch 48/100: Train Loss=12.1012, Val Loss=11.8933, Val Acc=0.0960
# Epoch 49/100: Train Loss=11.5496, Val Loss=9.6793, Val Acc=0.1770
# Epoch 50/100: Train Loss=11.9684, Val Loss=11.4756, Val Acc=0.1000
# Epoch 51/100: Train Loss=12.1655, Val Loss=13.3038, Val Acc=0.0960
# Epoch 52/100: Train Loss=11.4084, Val Loss=11.5681, Val Acc=0.1770
# Epoch 53/100: Train Loss=11.7572, Val Loss=13.4064, Val Acc=0.1000
# Epoch 54/100: Train Loss=12.7043, Val Loss=12.2712, Val Acc=0.0960
# Epoch 55/100: Train Loss=12.1984, Val Loss=10.7953, Val Acc=0.1770
# Epoch 56/100: Train Loss=12.1210, Val Loss=11.5117, Val Acc=0.1000
# Epoch 57/100: Train Loss=11.8530, Val Loss=9.5929, Val Acc=0.0960
# Epoch 58/100: Train Loss=11.8359, Val Loss=10.0016, Val Acc=0.1770
# Epoch 59/100: Train Loss=12.0604, Val Loss=11.5156, Val Acc=0.1000
# Epoch 60/100: Train Loss=11.9463, Val Loss=12.2706, Val Acc=0.0960
# Epoch 61/100: Train Loss=11.5461, Val Loss=9.9259, Val Acc=0.1770
# Epoch 62/100: Train Loss=12.0870, Val Loss=11.0597, Val Acc=0.1000
# Epoch 63/100: Train Loss=11.5501, Val Loss=13.3644, Val Acc=0.0960
# Epoch 64/100: Train Loss=11.3173, Val Loss=12.5562, Val Acc=0.1770
# Epoch 65/100: Train Loss=11.7785, Val Loss=14.2919, Val Acc=0.1000
# Epoch 66/100: Train Loss=11.6245, Val Loss=12.0053, Val Acc=0.0960
# Epoch 67/100: Train Loss=11.7674, Val Loss=12.7823, Val Acc=0.1770
# Epoch 68/100: Train Loss=12.1863, Val Loss=14.7379, Val Acc=0.1000
# Epoch 69/100: Train Loss=11.8968, Val Loss=14.6636, Val Acc=0.0960
# Epoch 70/100: Train Loss=12.2908, Val Loss=10.6174, Val Acc=0.1770
# Epoch 71/100: Train Loss=12.5139, Val Loss=10.6777, Val Acc=0.1000
# Epoch 72/100: Train Loss=11.4555, Val Loss=12.9465, Val Acc=0.0960
# Epoch 73/100: Train Loss=12.0374, Val Loss=11.2637, Val Acc=0.1770
# Epoch 74/100: Train Loss=11.6259, Val Loss=12.6200, Val Acc=0.1000
# Epoch 75/100: Train Loss=11.4011, Val Loss=12.1910, Val Acc=0.0960
# Epoch 76/100: Train Loss=11.0347, Val Loss=9.8839, Val Acc=0.1770
# Epoch 77/100: Train Loss=12.3234, Val Loss=11.7130, Val Acc=0.1000
# Epoch 78/100: Train Loss=12.4589, Val Loss=12.3105, Val Acc=0.0960
# Epoch 79/100: Train Loss=11.5640, Val Loss=11.4024, Val Acc=0.1770
# Epoch 80/100: Train Loss=11.3350, Val Loss=15.1899, Val Acc=0.1000
# Epoch 81/100: Train Loss=11.6002, Val Loss=13.3209, Val Acc=0.0960
# Epoch 82/100: Train Loss=11.4554, Val Loss=10.3294, Val Acc=0.1770
# Epoch 83/100: Train Loss=12.2143, Val Loss=13.7243, Val Acc=0.1000
# Epoch 84/100: Train Loss=12.2719, Val Loss=13.9940, Val Acc=0.0960
# Epoch 85/100: Train Loss=11.2259, Val Loss=11.1461, Val Acc=0.1770
# Epoch 86/100: Train Loss=11.4992, Val Loss=13.4928, Val Acc=0.1000
# Epoch 87/100: Train Loss=12.0399, Val Loss=12.4228, Val Acc=0.0960
# Epoch 88/100: Train Loss=11.4825, Val Loss=12.5977, Val Acc=0.1770
# Epoch 89/100: Train Loss=11.3521, Val Loss=11.6967, Val Acc=0.1000
# Epoch 90/100: Train Loss=12.0431, Val Loss=10.1226, Val Acc=0.0960
# Epoch 91/100: Train Loss=11.6514, Val Loss=8.6305, Val Acc=0.1770
# Epoch 92/100: Train Loss=11.6603, Val Loss=11.8643, Val Acc=0.1000
# Epoch 93/100: Train Loss=12.1566, Val Loss=13.8792, Val Acc=0.0960
# Epoch 94/100: Train Loss=11.8211, Val Loss=12.5781, Val Acc=0.1770
# Epoch 95/100: Train Loss=11.7550, Val Loss=13.3816, Val Acc=0.1000
# Epoch 96/100: Train Loss=11.6062, Val Loss=10.3955, Val Acc=0.0960
# Epoch 97/100: Train Loss=12.2304, Val Loss=10.1210, Val Acc=0.1770
# Epoch 98/100: Train Loss=11.8033, Val Loss=12.1896, Val Acc=0.1000
# Epoch 99/100: Train Loss=11.7127, Val Loss=12.6443, Val Acc=0.0960
# Epoch 100/100: Train Loss=11.6163, Val Loss=9.4166, Val Acc=0.1770
# WD=5 -> Val Loss: 8.6305
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Exp2_ValLoss_WD_0.0</td><td>▁█</td></tr><tr><td>Exp2_ValLoss_WD_0.0001</td><td>▁█</td></tr><tr><td>Exp2_ValLoss_WD_0.001</td><td>▁█</td></tr><tr><td>Exp2_ValLoss_WD_0.01</td><td>▁█</td></tr><tr><td>Exp2_ValLoss_WD_1</td><td>▁█</td></tr><tr><td>Exp2_ValLoss_WD_2</td><td>█▁</td></tr><tr><td>Exp2_ValLoss_WD_5</td><td>█▁</td></tr><tr><td>epoch</td><td>▁▇▂▄█▃▄▆▇█▆▁▅▆▂▇▁▄▄▄▇█▄▄▄▁▂▆▇▂▃▅▁▃▃▇█▄▁▇</td></tr><tr><td>train_accuracy</td><td>█████████▇▇▇▇▆▁▁▁▁▁▁██████████▇▇▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▁▁▂▁▁▁▁▁▁▁▁▁▁▅▅▅█▇▇█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▇▇█</td></tr><tr><td>val_accuracy</td><td>████████▇▇▇▇▇▂▁▁▁▁▁▁████████████▇▇▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁▄▇▇█▇▆█▆█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▆▄▆▅█▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Exp2_ValLoss_WD_0.0</td><td>0.22383</td></tr><tr><td>Exp2_ValLoss_WD_0.0001</td><td>0.217</td></tr><tr><td>Exp2_ValLoss_WD_0.001</td><td>0.21774</td></tr><tr><td>Exp2_ValLoss_WD_0.01</td><td>0.44732</td></tr><tr><td>Exp2_ValLoss_WD_1</td><td>4.18597</td></tr><tr><td>Exp2_ValLoss_WD_2</td><td>4.66071</td></tr><tr><td>Exp2_ValLoss_WD_5</td><td>8.63055</td></tr><tr><td>epoch</td><td>100</td></tr><tr><td>train_accuracy</td><td>0.121</td></tr><tr><td>train_loss</td><td>11.61631</td></tr><tr><td>val_accuracy</td><td>0.177</td></tr><tr><td>val_loss</td><td>9.41665</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">genial-surf-2</strong> at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/d3hxg6xk' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/d3hxg6xk</a><br> View project at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250216_185145-d3hxg6xk/logs</code>

# %% [markdown]
# **RESULT ANALYSIS :**
#
#   Our experiments varied the L2 weight decay coefficient across a wide range. The results indicate that:
#   - **Low Weight Decay (0.0, 0.0001, 0.001):**
#     These settings yielded the best generalization performance with final validation losses around **0.217–0.224**. This suggests that a small amount of or even no weight decay is sufficient for this task.
#   - **Moderate to High Weight Decay (0.01):**
#     Increasing weight decay to 0.01 led to a notable increase in validation loss (~**0.4473**), indicating that the regularization is starting to impede the model’s capacity to fit the data.
#   - **Excessive Weight Decay (1, 2, 5):**
#     When very high weight decay values were used, the model’s performance deteriorated drastically, with validation losses rising to **4.1860** for 1, **4.6607** for 2, and **8.6305** for 5. These results clearly demonstrate that over-regularization can severely hinder the learning process.
#
# - **Overall Assessment:**
#   The experiments highlight that minimal weight decay (around **0.0001–0.001**) provides the best balance between preventing overfitting and preserving model capacity. The wandb run history confirms that the model is highly sensitive to the weight decay magnitude, emphasizing the need for careful hyperparameter tuning in regularization.
#
# *View the detailed run metrics on the wandb dashboard for further insights.*

# %% [markdown]
# ### **C. Hidden Units Tuning:**
#    With weight decay turned off, the number of hidden units is varied (10, 30, 100, 130, 170, and 200) to identify the best model capacity.

# %%
# Reinitialize wandb if needed.
if wandb.run is None:
    wandb.init(
        project="usps-digit-classification",
        settings=wandb.Settings(init_timeout=600)
    )

hidden_units_values = [10, 30, 100, 130, 170, 200]
results_hu = {}

for hu in hidden_units_values:
    config_hu = {
        'hidden_units': hu,
        'dropout_rate': 0.5,
        'weight_decay': 0.0,
        'learning_rate': 0.40,
        'momentum': 0.9,
        'num_epochs': 100,
        'batch_size': 100
    }
    print(f"\nRunning Experiment 3 with hidden units = {hu}")
    val_loss, _, _ = run_experiment(config_hu)
    results_hu[hu] = val_loss
    print(f"Hidden Units={hu} -> Val Loss: {val_loss:.4f}")
    wandb.log({f"Exp3_ValLoss_HU_{hu}": val_loss})

# (Optional) Locally display the plot:
plt.figure(figsize=(8, 5))
plt.plot(hidden_units_values, [results_hu[hu] for hu in hidden_units_values], marker='o')
plt.xlabel('Number of Hidden Units')
plt.ylabel('Validation Loss')
plt.title('Experiment 3: Val Loss vs. Hidden Units')
plt.grid(True)
plt.show()

wandb.finish()  # End this run when done.
# Out:
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/content/wandb/run-20250216_185858-xb2kk7ql</code>
# Syncing run <strong><a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/xb2kk7ql' target="_blank">vague-elevator-3</a></strong> to <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification</a>
#  View run at <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/xb2kk7ql' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/xb2kk7ql</a>
# Running Experiment 3 with hidden units = 10
# Epoch 1/100: Train Loss=2.2457, Val Loss=2.0196, Val Acc=0.3900
# Epoch 2/100: Train Loss=1.8201, Val Loss=1.4845, Val Acc=0.4800
# Epoch 3/100: Train Loss=1.5179, Val Loss=1.1911, Val Acc=0.6340
# Epoch 4/100: Train Loss=1.3488, Val Loss=1.0288, Val Acc=0.7430
# Epoch 5/100: Train Loss=1.2585, Val Loss=0.8908, Val Acc=0.7150
# Epoch 6/100: Train Loss=1.2375, Val Loss=0.8639, Val Acc=0.7050
# Epoch 7/100: Train Loss=1.2264, Val Loss=0.8214, Val Acc=0.7240
# Epoch 8/100: Train Loss=1.1642, Val Loss=0.7689, Val Acc=0.7580
# Epoch 9/100: Train Loss=1.1911, Val Loss=0.7511, Val Acc=0.7980
# Epoch 10/100: Train Loss=1.1721, Val Loss=0.7653, Val Acc=0.7240
# Epoch 11/100: Train Loss=1.1458, Val Loss=0.7330, Val Acc=0.7950
# Epoch 12/100: Train Loss=1.1181, Val Loss=0.7037, Val Acc=0.7980
# Epoch 13/100: Train Loss=1.1001, Val Loss=0.7303, Val Acc=0.7740
# Epoch 14/100: Train Loss=1.1370, Val Loss=0.6812, Val Acc=0.8150
# Epoch 15/100: Train Loss=1.0942, Val Loss=0.6922, Val Acc=0.8010
# Epoch 16/100: Train Loss=1.0811, Val Loss=0.6510, Val Acc=0.8110
# Epoch 17/100: Train Loss=1.0752, Val Loss=0.6604, Val Acc=0.8150
# Epoch 18/100: Train Loss=1.0371, Val Loss=0.6167, Val Acc=0.8210
# Epoch 19/100: Train Loss=1.1097, Val Loss=0.6517, Val Acc=0.8110
# Epoch 20/100: Train Loss=1.0610, Val Loss=0.6187, Val Acc=0.8320
# Epoch 21/100: Train Loss=1.0325, Val Loss=0.6252, Val Acc=0.8190
# Epoch 22/100: Train Loss=1.1001, Val Loss=0.6335, Val Acc=0.8310
# Epoch 23/100: Train Loss=1.0475, Val Loss=0.6190, Val Acc=0.8430
# Epoch 24/100: Train Loss=1.0637, Val Loss=0.6125, Val Acc=0.8420
# Epoch 25/100: Train Loss=1.0204, Val Loss=0.6312, Val Acc=0.8260
# Epoch 26/100: Train Loss=1.0545, Val Loss=0.6178, Val Acc=0.8480
# Epoch 27/100: Train Loss=1.0760, Val Loss=0.6482, Val Acc=0.8340
# Epoch 28/100: Train Loss=1.0056, Val Loss=0.6126, Val Acc=0.8460
# Epoch 29/100: Train Loss=1.0184, Val Loss=0.6046, Val Acc=0.8260
# Epoch 30/100: Train Loss=1.0141, Val Loss=0.5924, Val Acc=0.8550
# Epoch 31/100: Train Loss=1.0042, Val Loss=0.6068, Val Acc=0.8370
# Epoch 32/100: Train Loss=0.9880, Val Loss=0.6010, Val Acc=0.8460
# Epoch 33/100: Train Loss=1.0159, Val Loss=0.5957, Val Acc=0.8530
# Epoch 34/100: Train Loss=1.0013, Val Loss=0.5926, Val Acc=0.8330
# Epoch 35/100: Train Loss=0.9603, Val Loss=0.5973, Val Acc=0.8420
# Epoch 36/100: Train Loss=1.0102, Val Loss=0.6038, Val Acc=0.8330
# Epoch 37/100: Train Loss=0.9943, Val Loss=0.6074, Val Acc=0.8360
# Epoch 38/100: Train Loss=1.0189, Val Loss=0.5864, Val Acc=0.8480
# Epoch 39/100: Train Loss=1.0334, Val Loss=0.6028, Val Acc=0.8300
# Epoch 40/100: Train Loss=1.0010, Val Loss=0.6072, Val Acc=0.8440
# Epoch 41/100: Train Loss=1.0083, Val Loss=0.6013, Val Acc=0.8330
# Epoch 42/100: Train Loss=0.9652, Val Loss=0.5711, Val Acc=0.8550
# Epoch 43/100: Train Loss=0.9944, Val Loss=0.5906, Val Acc=0.8400
# Epoch 44/100: Train Loss=0.9712, Val Loss=0.5913, Val Acc=0.8260
# Epoch 45/100: Train Loss=0.9771, Val Loss=0.5970, Val Acc=0.8480
# Epoch 46/100: Train Loss=0.9744, Val Loss=0.5847, Val Acc=0.8540
# Epoch 47/100: Train Loss=0.9895, Val Loss=0.5721, Val Acc=0.8500
# Epoch 48/100: Train Loss=0.9825, Val Loss=0.6011, Val Acc=0.8520
# Epoch 49/100: Train Loss=0.9689, Val Loss=0.5678, Val Acc=0.8460
# Epoch 50/100: Train Loss=0.9325, Val Loss=0.5779, Val Acc=0.8530
# Epoch 51/100: Train Loss=0.9694, Val Loss=0.5803, Val Acc=0.8480
# Epoch 52/100: Train Loss=0.9341, Val Loss=0.5841, Val Acc=0.8370
# Epoch 53/100: Train Loss=0.9263, Val Loss=0.5612, Val Acc=0.8470
# Epoch 54/100: Train Loss=0.9680, Val Loss=0.5754, Val Acc=0.8390
# Epoch 55/100: Train Loss=0.9268, Val Loss=0.5681, Val Acc=0.8280
# Epoch 56/100: Train Loss=0.9482, Val Loss=0.5733, Val Acc=0.8390
# Epoch 57/100: Train Loss=0.9279, Val Loss=0.5878, Val Acc=0.8330
# Epoch 58/100: Train Loss=0.9432, Val Loss=0.5803, Val Acc=0.8570
# Epoch 59/100: Train Loss=0.9335, Val Loss=0.5881, Val Acc=0.8480
# Epoch 60/100: Train Loss=0.9925, Val Loss=0.5852, Val Acc=0.8300
# Epoch 61/100: Train Loss=0.9529, Val Loss=0.5724, Val Acc=0.8510
# Epoch 62/100: Train Loss=0.9016, Val Loss=0.5891, Val Acc=0.8270
# Epoch 63/100: Train Loss=0.9235, Val Loss=0.5510, Val Acc=0.8510
# Epoch 64/100: Train Loss=0.8764, Val Loss=0.5750, Val Acc=0.8290
# Epoch 65/100: Train Loss=0.9709, Val Loss=0.5861, Val Acc=0.8420
# Epoch 66/100: Train Loss=0.9549, Val Loss=0.5782, Val Acc=0.8580
# Epoch 67/100: Train Loss=0.9285, Val Loss=0.5828, Val Acc=0.8330
# Epoch 68/100: Train Loss=0.9236, Val Loss=0.5752, Val Acc=0.8390
# Epoch 69/100: Train Loss=0.9203, Val Loss=0.5920, Val Acc=0.8240
# Epoch 70/100: Train Loss=0.9281, Val Loss=0.5699, Val Acc=0.8530
# Epoch 71/100: Train Loss=0.8995, Val Loss=0.5874, Val Acc=0.8440
# Epoch 72/100: Train Loss=0.9292, Val Loss=0.5772, Val Acc=0.8420
# Epoch 73/100: Train Loss=0.8384, Val Loss=0.5879, Val Acc=0.8380
# Epoch 74/100: Train Loss=0.9637, Val Loss=0.5601, Val Acc=0.8510
# Epoch 75/100: Train Loss=0.8608, Val Loss=0.5811, Val Acc=0.8290
# Epoch 76/100: Train Loss=0.9010, Val Loss=0.5516, Val Acc=0.8600
# Epoch 77/100: Train Loss=0.8812, Val Loss=0.5733, Val Acc=0.8390
# Epoch 78/100: Train Loss=0.8495, Val Loss=0.5524, Val Acc=0.8570
# Epoch 79/100: Train Loss=0.9004, Val Loss=0.5644, Val Acc=0.8420
# Epoch 80/100: Train Loss=0.8508, Val Loss=0.5587, Val Acc=0.8590
# Epoch 81/100: Train Loss=0.8901, Val Loss=0.5604, Val Acc=0.8490
# Epoch 82/100: Train Loss=0.8999, Val Loss=0.5775, Val Acc=0.8560
# Epoch 83/100: Train Loss=0.8556, Val Loss=0.5567, Val Acc=0.8590
# Epoch 84/100: Train Loss=0.8527, Val Loss=0.5422, Val Acc=0.8540
# Epoch 85/100: Train Loss=0.8933, Val Loss=0.5555, Val Acc=0.8570
# Epoch 86/100: Train Loss=0.8522, Val Loss=0.5454, Val Acc=0.8620
# Epoch 87/100: Train Loss=0.8713, Val Loss=0.5365, Val Acc=0.8670
# Epoch 88/100: Train Loss=0.8334, Val Loss=0.5279, Val Acc=0.8660
# Epoch 89/100: Train Loss=0.8502, Val Loss=0.5230, Val Acc=0.8720
# Epoch 90/100: Train Loss=0.8329, Val Loss=0.5307, Val Acc=0.8690
# Epoch 91/100: Train Loss=0.7874, Val Loss=0.4960, Val Acc=0.8740
# Epoch 92/100: Train Loss=0.8239, Val Loss=0.5340, Val Acc=0.8590
# Epoch 93/100: Train Loss=0.8448, Val Loss=0.5239, Val Acc=0.8690
# Epoch 94/100: Train Loss=0.8219, Val Loss=0.5423, Val Acc=0.8630
# Epoch 95/100: Train Loss=0.8833, Val Loss=0.5245, Val Acc=0.8700
# Epoch 96/100: Train Loss=0.8601, Val Loss=0.5324, Val Acc=0.8720
# Epoch 97/100: Train Loss=0.8452, Val Loss=0.5499, Val Acc=0.8510
# Epoch 98/100: Train Loss=0.8337, Val Loss=0.5013, Val Acc=0.8860
# Epoch 99/100: Train Loss=0.8745, Val Loss=0.5311, Val Acc=0.8690
# Epoch 100/100: Train Loss=0.8363, Val Loss=0.5246, Val Acc=0.8710
# Hidden Units=10 -> Val Loss: 0.4960
#
# Running Experiment 3 with hidden units = 30
# Epoch 1/100: Train Loss=2.2109, Val Loss=1.8204, Val Acc=0.4170
# Epoch 2/100: Train Loss=1.5903, Val Loss=1.1482, Val Acc=0.7090
# Epoch 3/100: Train Loss=1.1216, Val Loss=0.7640, Val Acc=0.7990
# Epoch 4/100: Train Loss=0.7966, Val Loss=0.5069, Val Acc=0.8610
# Epoch 5/100: Train Loss=0.6687, Val Loss=0.4488, Val Acc=0.8860
# Epoch 6/100: Train Loss=0.5597, Val Loss=0.3657, Val Acc=0.9010
# Epoch 7/100: Train Loss=0.5345, Val Loss=0.3629, Val Acc=0.9110
# Epoch 8/100: Train Loss=0.4802, Val Loss=0.3079, Val Acc=0.9070
# Epoch 9/100: Train Loss=0.4090, Val Loss=0.2943, Val Acc=0.9130
# Epoch 10/100: Train Loss=0.4011, Val Loss=0.2791, Val Acc=0.9270
# Epoch 11/100: Train Loss=0.3766, Val Loss=0.2704, Val Acc=0.9180
# Epoch 12/100: Train Loss=0.3788, Val Loss=0.2721, Val Acc=0.9210
# Epoch 13/100: Train Loss=0.3345, Val Loss=0.2683, Val Acc=0.9270
# Epoch 14/100: Train Loss=0.3195, Val Loss=0.2606, Val Acc=0.9290
# Epoch 15/100: Train Loss=0.3308, Val Loss=0.2631, Val Acc=0.9290
# Epoch 16/100: Train Loss=0.3047, Val Loss=0.2523, Val Acc=0.9240
# Epoch 17/100: Train Loss=0.3159, Val Loss=0.2563, Val Acc=0.9330
# Epoch 18/100: Train Loss=0.2669, Val Loss=0.2506, Val Acc=0.9300
# Epoch 19/100: Train Loss=0.2569, Val Loss=0.2653, Val Acc=0.9220
# Epoch 20/100: Train Loss=0.2431, Val Loss=0.2389, Val Acc=0.9310
# Epoch 21/100: Train Loss=0.2721, Val Loss=0.2505, Val Acc=0.9310
# Epoch 22/100: Train Loss=0.2420, Val Loss=0.2472, Val Acc=0.9340
# Epoch 23/100: Train Loss=0.2445, Val Loss=0.2570, Val Acc=0.9210
# Epoch 24/100: Train Loss=0.2562, Val Loss=0.2424, Val Acc=0.9330
# Epoch 25/100: Train Loss=0.2382, Val Loss=0.2445, Val Acc=0.9290
# Epoch 26/100: Train Loss=0.1938, Val Loss=0.2419, Val Acc=0.9320
# Epoch 27/100: Train Loss=0.2029, Val Loss=0.2431, Val Acc=0.9260
# Epoch 28/100: Train Loss=0.2329, Val Loss=0.2459, Val Acc=0.9290
# Epoch 29/100: Train Loss=0.2387, Val Loss=0.2497, Val Acc=0.9350
# Epoch 30/100: Train Loss=0.2318, Val Loss=0.2508, Val Acc=0.9280
# Epoch 31/100: Train Loss=0.2183, Val Loss=0.2466, Val Acc=0.9290
# Epoch 32/100: Train Loss=0.2140, Val Loss=0.2529, Val Acc=0.9250
# Epoch 33/100: Train Loss=0.2251, Val Loss=0.2569, Val Acc=0.9310
# Epoch 34/100: Train Loss=0.1874, Val Loss=0.2501, Val Acc=0.9300
# Epoch 35/100: Train Loss=0.1874, Val Loss=0.2378, Val Acc=0.9300
# Epoch 36/100: Train Loss=0.2142, Val Loss=0.2691, Val Acc=0.9280
# Epoch 37/100: Train Loss=0.2086, Val Loss=0.2632, Val Acc=0.9250
# Epoch 38/100: Train Loss=0.2084, Val Loss=0.2588, Val Acc=0.9260
# Epoch 39/100: Train Loss=0.1958, Val Loss=0.2635, Val Acc=0.9300
# Epoch 40/100: Train Loss=0.1937, Val Loss=0.2541, Val Acc=0.9330
# Epoch 41/100: Train Loss=0.1838, Val Loss=0.2509, Val Acc=0.9300
# Epoch 42/100: Train Loss=0.1664, Val Loss=0.2530, Val Acc=0.9370
# Epoch 43/100: Train Loss=0.1802, Val Loss=0.2844, Val Acc=0.9250
# Epoch 44/100: Train Loss=0.1936, Val Loss=0.2500, Val Acc=0.9320
# Epoch 45/100: Train Loss=0.1585, Val Loss=0.2582, Val Acc=0.9300
# Epoch 46/100: Train Loss=0.1957, Val Loss=0.2665, Val Acc=0.9290
# Epoch 47/100: Train Loss=0.1485, Val Loss=0.2663, Val Acc=0.9290
# Epoch 48/100: Train Loss=0.1523, Val Loss=0.2765, Val Acc=0.9290
# Epoch 49/100: Train Loss=0.1663, Val Loss=0.2739, Val Acc=0.9280
# Epoch 50/100: Train Loss=0.1513, Val Loss=0.2811, Val Acc=0.9250
# Epoch 51/100: Train Loss=0.1441, Val Loss=0.2868, Val Acc=0.9280
# Epoch 52/100: Train Loss=0.1548, Val Loss=0.2843, Val Acc=0.9320
# Epoch 53/100: Train Loss=0.1210, Val Loss=0.2797, Val Acc=0.9250
# Epoch 54/100: Train Loss=0.1342, Val Loss=0.2775, Val Acc=0.9310
# Epoch 55/100: Train Loss=0.1553, Val Loss=0.3012, Val Acc=0.9250
# Epoch 56/100: Train Loss=0.1501, Val Loss=0.2909, Val Acc=0.9260
# Epoch 57/100: Train Loss=0.1440, Val Loss=0.2902, Val Acc=0.9250
# Epoch 58/100: Train Loss=0.1417, Val Loss=0.2918, Val Acc=0.9290
# Epoch 59/100: Train Loss=0.1488, Val Loss=0.3083, Val Acc=0.9250
# Epoch 60/100: Train Loss=0.1612, Val Loss=0.2989, Val Acc=0.9260
# Epoch 61/100: Train Loss=0.1388, Val Loss=0.3010, Val Acc=0.9250
# Epoch 62/100: Train Loss=0.1281, Val Loss=0.2910, Val Acc=0.9260
# Epoch 63/100: Train Loss=0.1340, Val Loss=0.2956, Val Acc=0.9260
# Epoch 64/100: Train Loss=0.1427, Val Loss=0.3099, Val Acc=0.9270
# Epoch 65/100: Train Loss=0.1360, Val Loss=0.2960, Val Acc=0.9270
# Epoch 66/100: Train Loss=0.1272, Val Loss=0.2907, Val Acc=0.9320
# Epoch 67/100: Train Loss=0.1336, Val Loss=0.2989, Val Acc=0.9290
# Epoch 68/100: Train Loss=0.1580, Val Loss=0.3188, Val Acc=0.9240
# Epoch 69/100: Train Loss=0.1415, Val Loss=0.3258, Val Acc=0.9190
# Epoch 70/100: Train Loss=0.1304, Val Loss=0.3074, Val Acc=0.9250
# Epoch 71/100: Train Loss=0.1559, Val Loss=0.3248, Val Acc=0.9260
# Epoch 72/100: Train Loss=0.1550, Val Loss=0.3069, Val Acc=0.9260
# Epoch 73/100: Train Loss=0.1417, Val Loss=0.3092, Val Acc=0.9220
# Epoch 74/100: Train Loss=0.1273, Val Loss=0.3076, Val Acc=0.9240
# Epoch 75/100: Train Loss=0.1514, Val Loss=0.3222, Val Acc=0.9240
# Epoch 76/100: Train Loss=0.1378, Val Loss=0.3344, Val Acc=0.9210
# Epoch 77/100: Train Loss=0.1306, Val Loss=0.3257, Val Acc=0.9220
# Epoch 78/100: Train Loss=0.1085, Val Loss=0.3137, Val Acc=0.9260
# Epoch 79/100: Train Loss=0.1057, Val Loss=0.3257, Val Acc=0.9280
# Epoch 80/100: Train Loss=0.1127, Val Loss=0.3256, Val Acc=0.9250
# Epoch 81/100: Train Loss=0.1155, Val Loss=0.3312, Val Acc=0.9230
# Epoch 82/100: Train Loss=0.1237, Val Loss=0.3137, Val Acc=0.9240
# Epoch 83/100: Train Loss=0.1194, Val Loss=0.3115, Val Acc=0.9290
# Epoch 84/100: Train Loss=0.1002, Val Loss=0.3130, Val Acc=0.9250
# Epoch 85/100: Train Loss=0.1389, Val Loss=0.3297, Val Acc=0.9250
# Epoch 86/100: Train Loss=0.1254, Val Loss=0.3482, Val Acc=0.9200
# Epoch 87/100: Train Loss=0.1298, Val Loss=0.3425, Val Acc=0.9210
# Epoch 88/100: Train Loss=0.1399, Val Loss=0.3488, Val Acc=0.9180
# Epoch 89/100: Train Loss=0.1258, Val Loss=0.3557, Val Acc=0.9220
# Epoch 90/100: Train Loss=0.1362, Val Loss=0.3287, Val Acc=0.9260
# Epoch 91/100: Train Loss=0.1185, Val Loss=0.3323, Val Acc=0.9250
# Epoch 92/100: Train Loss=0.1270, Val Loss=0.3374, Val Acc=0.9220
# Epoch 93/100: Train Loss=0.1037, Val Loss=0.3138, Val Acc=0.9260
# Epoch 94/100: Train Loss=0.1364, Val Loss=0.3491, Val Acc=0.9220
# Epoch 95/100: Train Loss=0.0963, Val Loss=0.3414, Val Acc=0.9250
# Epoch 96/100: Train Loss=0.1275, Val Loss=0.3253, Val Acc=0.9260
# Epoch 97/100: Train Loss=0.1118, Val Loss=0.3147, Val Acc=0.9260
# Epoch 98/100: Train Loss=0.1259, Val Loss=0.3364, Val Acc=0.9240
# Epoch 99/100: Train Loss=0.1328, Val Loss=0.3461, Val Acc=0.9280
# Epoch 100/100: Train Loss=0.1197, Val Loss=0.3238, Val Acc=0.9240
# Hidden Units=30 -> Val Loss: 0.2378
#
# Running Experiment 3 with hidden units = 100
# Epoch 1/100: Train Loss=2.2553, Val Loss=1.7502, Val Acc=0.4440
# Epoch 2/100: Train Loss=1.3733, Val Loss=0.8794, Val Acc=0.7540
# Epoch 3/100: Train Loss=0.7763, Val Loss=0.4968, Val Acc=0.8400
# Epoch 4/100: Train Loss=0.4780, Val Loss=0.3317, Val Acc=0.8940
# Epoch 5/100: Train Loss=0.3358, Val Loss=0.3133, Val Acc=0.9100
# Epoch 6/100: Train Loss=0.3180, Val Loss=0.2743, Val Acc=0.9230
# Epoch 7/100: Train Loss=0.2924, Val Loss=0.3079, Val Acc=0.9050
# Epoch 8/100: Train Loss=0.2322, Val Loss=0.2549, Val Acc=0.9250
# Epoch 9/100: Train Loss=0.2025, Val Loss=0.2396, Val Acc=0.9310
# Epoch 10/100: Train Loss=0.1830, Val Loss=0.2466, Val Acc=0.9300
# Epoch 11/100: Train Loss=0.1684, Val Loss=0.2456, Val Acc=0.9340
# Epoch 12/100: Train Loss=0.1556, Val Loss=0.2426, Val Acc=0.9340
# Epoch 13/100: Train Loss=0.1569, Val Loss=0.2418, Val Acc=0.9310
# Epoch 14/100: Train Loss=0.1470, Val Loss=0.2370, Val Acc=0.9270
# Epoch 15/100: Train Loss=0.1380, Val Loss=0.2394, Val Acc=0.9350
# Epoch 16/100: Train Loss=0.1032, Val Loss=0.2405, Val Acc=0.9390
# Epoch 17/100: Train Loss=0.1047, Val Loss=0.2459, Val Acc=0.9310
# Epoch 18/100: Train Loss=0.1075, Val Loss=0.2603, Val Acc=0.9310
# Epoch 19/100: Train Loss=0.0985, Val Loss=0.2560, Val Acc=0.9310
# Epoch 20/100: Train Loss=0.0893, Val Loss=0.2433, Val Acc=0.9350
# Epoch 21/100: Train Loss=0.0898, Val Loss=0.2437, Val Acc=0.9300
# Epoch 22/100: Train Loss=0.0898, Val Loss=0.2285, Val Acc=0.9340
# Epoch 23/100: Train Loss=0.0880, Val Loss=0.2354, Val Acc=0.9360
# Epoch 24/100: Train Loss=0.0639, Val Loss=0.2446, Val Acc=0.9360
# Epoch 25/100: Train Loss=0.0778, Val Loss=0.2435, Val Acc=0.9360
# Epoch 26/100: Train Loss=0.0637, Val Loss=0.2456, Val Acc=0.9350
# Epoch 27/100: Train Loss=0.0697, Val Loss=0.2580, Val Acc=0.9350
# Epoch 28/100: Train Loss=0.0713, Val Loss=0.2484, Val Acc=0.9370
# Epoch 29/100: Train Loss=0.0623, Val Loss=0.2434, Val Acc=0.9370
# Epoch 30/100: Train Loss=0.0605, Val Loss=0.2520, Val Acc=0.9350
# Epoch 31/100: Train Loss=0.0521, Val Loss=0.2384, Val Acc=0.9360
# Epoch 32/100: Train Loss=0.0525, Val Loss=0.2457, Val Acc=0.9370
# Epoch 33/100: Train Loss=0.0577, Val Loss=0.2484, Val Acc=0.9370
# Epoch 34/100: Train Loss=0.0429, Val Loss=0.2656, Val Acc=0.9340
# Epoch 35/100: Train Loss=0.0546, Val Loss=0.2841, Val Acc=0.9350
# Epoch 36/100: Train Loss=0.0336, Val Loss=0.2680, Val Acc=0.9360
# Epoch 37/100: Train Loss=0.0461, Val Loss=0.2672, Val Acc=0.9350
# Epoch 38/100: Train Loss=0.0501, Val Loss=0.2579, Val Acc=0.9360
# Epoch 39/100: Train Loss=0.0446, Val Loss=0.2674, Val Acc=0.9350
# Epoch 40/100: Train Loss=0.0440, Val Loss=0.2678, Val Acc=0.9370
# Epoch 41/100: Train Loss=0.0442, Val Loss=0.2591, Val Acc=0.9380
# Epoch 42/100: Train Loss=0.0493, Val Loss=0.2570, Val Acc=0.9360
# Epoch 43/100: Train Loss=0.0518, Val Loss=0.2661, Val Acc=0.9350
# Epoch 44/100: Train Loss=0.0409, Val Loss=0.2635, Val Acc=0.9350
# Epoch 45/100: Train Loss=0.0418, Val Loss=0.2628, Val Acc=0.9340
# Epoch 46/100: Train Loss=0.0391, Val Loss=0.2741, Val Acc=0.9340
# Epoch 47/100: Train Loss=0.0399, Val Loss=0.2888, Val Acc=0.9300
# Epoch 48/100: Train Loss=0.0437, Val Loss=0.2904, Val Acc=0.9340
# Epoch 49/100: Train Loss=0.0373, Val Loss=0.2698, Val Acc=0.9360
# Epoch 50/100: Train Loss=0.0333, Val Loss=0.2844, Val Acc=0.9310
# Epoch 51/100: Train Loss=0.0376, Val Loss=0.2876, Val Acc=0.9330
# Epoch 52/100: Train Loss=0.0421, Val Loss=0.2686, Val Acc=0.9360
# Epoch 53/100: Train Loss=0.0343, Val Loss=0.2783, Val Acc=0.9330
# Epoch 54/100: Train Loss=0.0357, Val Loss=0.2736, Val Acc=0.9360
# Epoch 55/100: Train Loss=0.0279, Val Loss=0.2759, Val Acc=0.9370
# Epoch 56/100: Train Loss=0.0297, Val Loss=0.2750, Val Acc=0.9390
# Epoch 57/100: Train Loss=0.0218, Val Loss=0.2731, Val Acc=0.9370
# Epoch 58/100: Train Loss=0.0329, Val Loss=0.2876, Val Acc=0.9380
# Epoch 59/100: Train Loss=0.0294, Val Loss=0.3020, Val Acc=0.9330
# Epoch 60/100: Train Loss=0.0310, Val Loss=0.2906, Val Acc=0.9320
# Epoch 61/100: Train Loss=0.0294, Val Loss=0.2845, Val Acc=0.9360
# Epoch 62/100: Train Loss=0.0265, Val Loss=0.2794, Val Acc=0.9380
# Epoch 63/100: Train Loss=0.0287, Val Loss=0.2891, Val Acc=0.9320
# Epoch 64/100: Train Loss=0.0332, Val Loss=0.2905, Val Acc=0.9350
# Epoch 65/100: Train Loss=0.0259, Val Loss=0.2837, Val Acc=0.9380
# Epoch 66/100: Train Loss=0.0214, Val Loss=0.2776, Val Acc=0.9400
# Epoch 67/100: Train Loss=0.0273, Val Loss=0.2819, Val Acc=0.9360
# Epoch 68/100: Train Loss=0.0228, Val Loss=0.2812, Val Acc=0.9360
# Epoch 69/100: Train Loss=0.0297, Val Loss=0.2809, Val Acc=0.9350
# Epoch 70/100: Train Loss=0.0261, Val Loss=0.2792, Val Acc=0.9360
# Epoch 71/100: Train Loss=0.0247, Val Loss=0.2889, Val Acc=0.9320
# Epoch 72/100: Train Loss=0.0210, Val Loss=0.2791, Val Acc=0.9370
# Epoch 73/100: Train Loss=0.0308, Val Loss=0.2784, Val Acc=0.9390
# Epoch 74/100: Train Loss=0.0244, Val Loss=0.2919, Val Acc=0.9380
# Epoch 75/100: Train Loss=0.0254, Val Loss=0.2940, Val Acc=0.9350
# Epoch 76/100: Train Loss=0.0242, Val Loss=0.2895, Val Acc=0.9360
# Epoch 77/100: Train Loss=0.0250, Val Loss=0.2814, Val Acc=0.9370
# Epoch 78/100: Train Loss=0.0218, Val Loss=0.2797, Val Acc=0.9390
# Epoch 79/100: Train Loss=0.0175, Val Loss=0.2835, Val Acc=0.9340
# Epoch 80/100: Train Loss=0.0268, Val Loss=0.3037, Val Acc=0.9360
# Epoch 81/100: Train Loss=0.0213, Val Loss=0.3129, Val Acc=0.9360
# Epoch 82/100: Train Loss=0.0168, Val Loss=0.3001, Val Acc=0.9360
# Epoch 83/100: Train Loss=0.0273, Val Loss=0.2911, Val Acc=0.9400
# Epoch 84/100: Train Loss=0.0168, Val Loss=0.3000, Val Acc=0.9400
# Epoch 85/100: Train Loss=0.0230, Val Loss=0.2930, Val Acc=0.9380
# Epoch 86/100: Train Loss=0.0202, Val Loss=0.2865, Val Acc=0.9420
# Epoch 87/100: Train Loss=0.0226, Val Loss=0.2924, Val Acc=0.9390
# Epoch 88/100: Train Loss=0.0218, Val Loss=0.3046, Val Acc=0.9340
# Epoch 89/100: Train Loss=0.0233, Val Loss=0.3063, Val Acc=0.9320
# Epoch 90/100: Train Loss=0.0289, Val Loss=0.2995, Val Acc=0.9370
# Epoch 91/100: Train Loss=0.0249, Val Loss=0.3074, Val Acc=0.9360
# Epoch 92/100: Train Loss=0.0226, Val Loss=0.3092, Val Acc=0.9320
# Epoch 93/100: Train Loss=0.0254, Val Loss=0.2884, Val Acc=0.9390
# Epoch 94/100: Train Loss=0.0214, Val Loss=0.2941, Val Acc=0.9380
# Epoch 95/100: Train Loss=0.0263, Val Loss=0.2934, Val Acc=0.9350
# Epoch 96/100: Train Loss=0.0119, Val Loss=0.2968, Val Acc=0.9360
# Epoch 97/100: Train Loss=0.0163, Val Loss=0.3012, Val Acc=0.9360
# Epoch 98/100: Train Loss=0.0282, Val Loss=0.3048, Val Acc=0.9340
# Epoch 99/100: Train Loss=0.0167, Val Loss=0.3189, Val Acc=0.9330
# Epoch 100/100: Train Loss=0.0169, Val Loss=0.3136, Val Acc=0.9340
# Hidden Units=100 -> Val Loss: 0.2285
#
# Running Experiment 3 with hidden units = 130
# Epoch 1/100: Train Loss=2.2209, Val Loss=1.6295, Val Acc=0.3860
# Epoch 2/100: Train Loss=1.2528, Val Loss=0.7376, Val Acc=0.7700
# Epoch 3/100: Train Loss=0.6477, Val Loss=0.4063, Val Acc=0.8680
# Epoch 4/100: Train Loss=0.4213, Val Loss=0.3219, Val Acc=0.9000
# Epoch 5/100: Train Loss=0.3378, Val Loss=0.2703, Val Acc=0.9260
# Epoch 6/100: Train Loss=0.2764, Val Loss=0.2576, Val Acc=0.9290
# Epoch 7/100: Train Loss=0.2548, Val Loss=0.2434, Val Acc=0.9290
# Epoch 8/100: Train Loss=0.1811, Val Loss=0.2499, Val Acc=0.9300
# Epoch 9/100: Train Loss=0.2031, Val Loss=0.2355, Val Acc=0.9360
# Epoch 10/100: Train Loss=0.1679, Val Loss=0.2264, Val Acc=0.9320
# Epoch 11/100: Train Loss=0.1622, Val Loss=0.2330, Val Acc=0.9330
# Epoch 12/100: Train Loss=0.1373, Val Loss=0.2349, Val Acc=0.9320
# Epoch 13/100: Train Loss=0.1364, Val Loss=0.2283, Val Acc=0.9310
# Epoch 14/100: Train Loss=0.1111, Val Loss=0.2260, Val Acc=0.9330
# Epoch 15/100: Train Loss=0.1186, Val Loss=0.2240, Val Acc=0.9390
# Epoch 16/100: Train Loss=0.1045, Val Loss=0.2242, Val Acc=0.9340
# Epoch 17/100: Train Loss=0.0970, Val Loss=0.2167, Val Acc=0.9410
# Epoch 18/100: Train Loss=0.0956, Val Loss=0.2244, Val Acc=0.9370
# Epoch 19/100: Train Loss=0.0862, Val Loss=0.2189, Val Acc=0.9370
# Epoch 20/100: Train Loss=0.0902, Val Loss=0.2363, Val Acc=0.9390
# Epoch 21/100: Train Loss=0.0838, Val Loss=0.2272, Val Acc=0.9340
# Epoch 22/100: Train Loss=0.0748, Val Loss=0.2227, Val Acc=0.9370
# Epoch 23/100: Train Loss=0.0637, Val Loss=0.2320, Val Acc=0.9370
# Epoch 24/100: Train Loss=0.0694, Val Loss=0.2363, Val Acc=0.9390
# Epoch 25/100: Train Loss=0.0687, Val Loss=0.2343, Val Acc=0.9370
# Epoch 26/100: Train Loss=0.0592, Val Loss=0.2358, Val Acc=0.9400
# Epoch 27/100: Train Loss=0.0485, Val Loss=0.2382, Val Acc=0.9400
# Epoch 28/100: Train Loss=0.0756, Val Loss=0.2244, Val Acc=0.9370
# Epoch 29/100: Train Loss=0.0477, Val Loss=0.2297, Val Acc=0.9360
# Epoch 30/100: Train Loss=0.0414, Val Loss=0.2316, Val Acc=0.9370
# Epoch 31/100: Train Loss=0.0485, Val Loss=0.2347, Val Acc=0.9370
# Epoch 32/100: Train Loss=0.0478, Val Loss=0.2383, Val Acc=0.9370
# Epoch 33/100: Train Loss=0.0353, Val Loss=0.2362, Val Acc=0.9360
# Epoch 34/100: Train Loss=0.0406, Val Loss=0.2417, Val Acc=0.9380
# Epoch 35/100: Train Loss=0.0468, Val Loss=0.2430, Val Acc=0.9350
# Epoch 36/100: Train Loss=0.0416, Val Loss=0.2439, Val Acc=0.9350
# Epoch 37/100: Train Loss=0.0379, Val Loss=0.2469, Val Acc=0.9360
# Epoch 38/100: Train Loss=0.0326, Val Loss=0.2480, Val Acc=0.9390
# Epoch 39/100: Train Loss=0.0420, Val Loss=0.2510, Val Acc=0.9340
# Epoch 40/100: Train Loss=0.0274, Val Loss=0.2542, Val Acc=0.9370
# Epoch 41/100: Train Loss=0.0398, Val Loss=0.2632, Val Acc=0.9310
# Epoch 42/100: Train Loss=0.0290, Val Loss=0.2585, Val Acc=0.9390
# Epoch 43/100: Train Loss=0.0263, Val Loss=0.2560, Val Acc=0.9380
# Epoch 44/100: Train Loss=0.0282, Val Loss=0.2592, Val Acc=0.9390
# Epoch 45/100: Train Loss=0.0401, Val Loss=0.2682, Val Acc=0.9370
# Epoch 46/100: Train Loss=0.0232, Val Loss=0.2578, Val Acc=0.9370
# Epoch 47/100: Train Loss=0.0319, Val Loss=0.2554, Val Acc=0.9370
# Epoch 48/100: Train Loss=0.0278, Val Loss=0.2653, Val Acc=0.9410
# Epoch 49/100: Train Loss=0.0275, Val Loss=0.2678, Val Acc=0.9410
# Epoch 50/100: Train Loss=0.0181, Val Loss=0.2680, Val Acc=0.9360
# Epoch 51/100: Train Loss=0.0207, Val Loss=0.2743, Val Acc=0.9390
# Epoch 52/100: Train Loss=0.0228, Val Loss=0.2836, Val Acc=0.9390
# Epoch 53/100: Train Loss=0.0229, Val Loss=0.2845, Val Acc=0.9380
# Epoch 54/100: Train Loss=0.0165, Val Loss=0.2703, Val Acc=0.9420
# Epoch 55/100: Train Loss=0.0279, Val Loss=0.2644, Val Acc=0.9410
# Epoch 56/100: Train Loss=0.0357, Val Loss=0.2795, Val Acc=0.9410
# Epoch 57/100: Train Loss=0.0325, Val Loss=0.2680, Val Acc=0.9420
# Epoch 58/100: Train Loss=0.0208, Val Loss=0.2558, Val Acc=0.9370
# Epoch 59/100: Train Loss=0.0235, Val Loss=0.2654, Val Acc=0.9370
# Epoch 60/100: Train Loss=0.0276, Val Loss=0.2690, Val Acc=0.9390
# Epoch 61/100: Train Loss=0.0269, Val Loss=0.2663, Val Acc=0.9420
# Epoch 62/100: Train Loss=0.0187, Val Loss=0.2697, Val Acc=0.9420
# Epoch 63/100: Train Loss=0.0235, Val Loss=0.2802, Val Acc=0.9410
# Epoch 64/100: Train Loss=0.0121, Val Loss=0.2782, Val Acc=0.9390
# Epoch 65/100: Train Loss=0.0236, Val Loss=0.2679, Val Acc=0.9380
# Epoch 66/100: Train Loss=0.0197, Val Loss=0.2625, Val Acc=0.9410
# Epoch 67/100: Train Loss=0.0187, Val Loss=0.2741, Val Acc=0.9380
# Epoch 68/100: Train Loss=0.0186, Val Loss=0.2802, Val Acc=0.9400
# Epoch 69/100: Train Loss=0.0188, Val Loss=0.2702, Val Acc=0.9400
# Epoch 70/100: Train Loss=0.0203, Val Loss=0.2689, Val Acc=0.9370
# Epoch 71/100: Train Loss=0.0270, Val Loss=0.2689, Val Acc=0.9400
# Epoch 72/100: Train Loss=0.0224, Val Loss=0.2801, Val Acc=0.9420
# Epoch 73/100: Train Loss=0.0244, Val Loss=0.2783, Val Acc=0.9360
# Epoch 74/100: Train Loss=0.0134, Val Loss=0.2743, Val Acc=0.9390
# Epoch 75/100: Train Loss=0.0193, Val Loss=0.2657, Val Acc=0.9410
# Epoch 76/100: Train Loss=0.0219, Val Loss=0.2806, Val Acc=0.9370
# Epoch 77/100: Train Loss=0.0224, Val Loss=0.2804, Val Acc=0.9400
# Epoch 78/100: Train Loss=0.0162, Val Loss=0.2775, Val Acc=0.9390
# Epoch 79/100: Train Loss=0.0185, Val Loss=0.2700, Val Acc=0.9400
# Epoch 80/100: Train Loss=0.0139, Val Loss=0.2769, Val Acc=0.9350
# Epoch 81/100: Train Loss=0.0159, Val Loss=0.2678, Val Acc=0.9380
# Epoch 82/100: Train Loss=0.0163, Val Loss=0.2648, Val Acc=0.9410
# Epoch 83/100: Train Loss=0.0117, Val Loss=0.2751, Val Acc=0.9380
# Epoch 84/100: Train Loss=0.0221, Val Loss=0.2795, Val Acc=0.9400
# Epoch 85/100: Train Loss=0.0179, Val Loss=0.2770, Val Acc=0.9390
# Epoch 86/100: Train Loss=0.0133, Val Loss=0.2664, Val Acc=0.9390
# Epoch 87/100: Train Loss=0.0155, Val Loss=0.2632, Val Acc=0.9370
# Epoch 88/100: Train Loss=0.0194, Val Loss=0.2654, Val Acc=0.9380
# Epoch 89/100: Train Loss=0.0186, Val Loss=0.2772, Val Acc=0.9400
# Epoch 90/100: Train Loss=0.0108, Val Loss=0.2827, Val Acc=0.9400
# Epoch 91/100: Train Loss=0.0177, Val Loss=0.2733, Val Acc=0.9380
# Epoch 92/100: Train Loss=0.0158, Val Loss=0.2714, Val Acc=0.9370
# Epoch 93/100: Train Loss=0.0141, Val Loss=0.2805, Val Acc=0.9400
# Epoch 94/100: Train Loss=0.0145, Val Loss=0.2802, Val Acc=0.9420
# Epoch 95/100: Train Loss=0.0101, Val Loss=0.2828, Val Acc=0.9400
# Epoch 96/100: Train Loss=0.0144, Val Loss=0.2818, Val Acc=0.9410
# Epoch 97/100: Train Loss=0.0187, Val Loss=0.2851, Val Acc=0.9410
# Epoch 98/100: Train Loss=0.0149, Val Loss=0.2865, Val Acc=0.9400
# Epoch 99/100: Train Loss=0.0261, Val Loss=0.2862, Val Acc=0.9370
# Epoch 100/100: Train Loss=0.0125, Val Loss=0.2725, Val Acc=0.9370
# Hidden Units=130 -> Val Loss: 0.2167
#
# Running Experiment 3 with hidden units = 170
# Epoch 1/100: Train Loss=2.2852, Val Loss=1.9178, Val Acc=0.4360
# Epoch 2/100: Train Loss=1.3264, Val Loss=0.7882, Val Acc=0.7260
# Epoch 3/100: Train Loss=0.6016, Val Loss=0.4630, Val Acc=0.8470
# Epoch 4/100: Train Loss=0.3997, Val Loss=0.3531, Val Acc=0.8890
# Epoch 5/100: Train Loss=0.3242, Val Loss=0.3421, Val Acc=0.8870
# Epoch 6/100: Train Loss=0.2707, Val Loss=0.2673, Val Acc=0.9220
# Epoch 7/100: Train Loss=0.2346, Val Loss=0.2600, Val Acc=0.9260
# Epoch 8/100: Train Loss=0.1786, Val Loss=0.2514, Val Acc=0.9250
# Epoch 9/100: Train Loss=0.1649, Val Loss=0.2399, Val Acc=0.9340
# Epoch 10/100: Train Loss=0.1415, Val Loss=0.2376, Val Acc=0.9300
# Epoch 11/100: Train Loss=0.1526, Val Loss=0.2359, Val Acc=0.9300
# Epoch 12/100: Train Loss=0.1270, Val Loss=0.2357, Val Acc=0.9320
# Epoch 13/100: Train Loss=0.1292, Val Loss=0.2336, Val Acc=0.9340
# Epoch 14/100: Train Loss=0.1051, Val Loss=0.2376, Val Acc=0.9320
# Epoch 15/100: Train Loss=0.0947, Val Loss=0.2263, Val Acc=0.9380
# Epoch 16/100: Train Loss=0.0818, Val Loss=0.2305, Val Acc=0.9330
# Epoch 17/100: Train Loss=0.0943, Val Loss=0.2385, Val Acc=0.9280
# Epoch 18/100: Train Loss=0.0720, Val Loss=0.2347, Val Acc=0.9360
# Epoch 19/100: Train Loss=0.0816, Val Loss=0.2386, Val Acc=0.9310
# Epoch 20/100: Train Loss=0.0669, Val Loss=0.2338, Val Acc=0.9320
# Epoch 21/100: Train Loss=0.0720, Val Loss=0.2481, Val Acc=0.9360
# Epoch 22/100: Train Loss=0.0724, Val Loss=0.2426, Val Acc=0.9320
# Epoch 23/100: Train Loss=0.0626, Val Loss=0.2416, Val Acc=0.9340
# Epoch 24/100: Train Loss=0.0693, Val Loss=0.2325, Val Acc=0.9360
# Epoch 25/100: Train Loss=0.0707, Val Loss=0.2349, Val Acc=0.9350
# Epoch 26/100: Train Loss=0.0606, Val Loss=0.2398, Val Acc=0.9340
# Epoch 27/100: Train Loss=0.0522, Val Loss=0.2458, Val Acc=0.9400
# Epoch 28/100: Train Loss=0.0663, Val Loss=0.2375, Val Acc=0.9370
# Epoch 29/100: Train Loss=0.0536, Val Loss=0.2454, Val Acc=0.9340
# Epoch 30/100: Train Loss=0.0441, Val Loss=0.2450, Val Acc=0.9360
# Epoch 31/100: Train Loss=0.0391, Val Loss=0.2417, Val Acc=0.9330
# Epoch 32/100: Train Loss=0.0386, Val Loss=0.2526, Val Acc=0.9410
# Epoch 33/100: Train Loss=0.0384, Val Loss=0.2645, Val Acc=0.9380
# Epoch 34/100: Train Loss=0.0318, Val Loss=0.2674, Val Acc=0.9350
# Epoch 35/100: Train Loss=0.0354, Val Loss=0.2637, Val Acc=0.9400
# Epoch 36/100: Train Loss=0.0411, Val Loss=0.2567, Val Acc=0.9370
# Epoch 37/100: Train Loss=0.0303, Val Loss=0.2504, Val Acc=0.9380
# Epoch 38/100: Train Loss=0.0295, Val Loss=0.2552, Val Acc=0.9410
# Epoch 39/100: Train Loss=0.0324, Val Loss=0.2589, Val Acc=0.9380
# Epoch 40/100: Train Loss=0.0362, Val Loss=0.2555, Val Acc=0.9390
# Epoch 41/100: Train Loss=0.0340, Val Loss=0.2622, Val Acc=0.9330
# Epoch 42/100: Train Loss=0.0264, Val Loss=0.2567, Val Acc=0.9390
# Epoch 43/100: Train Loss=0.0281, Val Loss=0.2553, Val Acc=0.9350
# Epoch 44/100: Train Loss=0.0233, Val Loss=0.2682, Val Acc=0.9350
# Epoch 45/100: Train Loss=0.0288, Val Loss=0.2536, Val Acc=0.9380
# Epoch 46/100: Train Loss=0.0333, Val Loss=0.2627, Val Acc=0.9370
# Epoch 47/100: Train Loss=0.0260, Val Loss=0.2670, Val Acc=0.9380
# Epoch 48/100: Train Loss=0.0243, Val Loss=0.2623, Val Acc=0.9400
# Epoch 49/100: Train Loss=0.0234, Val Loss=0.2617, Val Acc=0.9380
# Epoch 50/100: Train Loss=0.0285, Val Loss=0.2791, Val Acc=0.9400
# Epoch 51/100: Train Loss=0.0265, Val Loss=0.2711, Val Acc=0.9340
# Epoch 52/100: Train Loss=0.0240, Val Loss=0.2697, Val Acc=0.9420
# Epoch 53/100: Train Loss=0.0308, Val Loss=0.2633, Val Acc=0.9410
# Epoch 54/100: Train Loss=0.0242, Val Loss=0.2632, Val Acc=0.9400
# Epoch 55/100: Train Loss=0.0199, Val Loss=0.2724, Val Acc=0.9390
# Epoch 56/100: Train Loss=0.0211, Val Loss=0.2630, Val Acc=0.9400
# Epoch 57/100: Train Loss=0.0216, Val Loss=0.2699, Val Acc=0.9320
# Epoch 58/100: Train Loss=0.0206, Val Loss=0.2612, Val Acc=0.9410
# Epoch 59/100: Train Loss=0.0179, Val Loss=0.2666, Val Acc=0.9390
# Epoch 60/100: Train Loss=0.0185, Val Loss=0.2635, Val Acc=0.9380
# Epoch 61/100: Train Loss=0.0160, Val Loss=0.2673, Val Acc=0.9390
# Epoch 62/100: Train Loss=0.0202, Val Loss=0.2660, Val Acc=0.9420
# Epoch 63/100: Train Loss=0.0175, Val Loss=0.2661, Val Acc=0.9380
# Epoch 64/100: Train Loss=0.0190, Val Loss=0.2681, Val Acc=0.9400
# Epoch 65/100: Train Loss=0.0202, Val Loss=0.2844, Val Acc=0.9370
# Epoch 66/100: Train Loss=0.0151, Val Loss=0.2804, Val Acc=0.9410
# Epoch 67/100: Train Loss=0.0208, Val Loss=0.2800, Val Acc=0.9350
# Epoch 68/100: Train Loss=0.0163, Val Loss=0.2755, Val Acc=0.9380
# Epoch 69/100: Train Loss=0.0191, Val Loss=0.2767, Val Acc=0.9390
# Epoch 70/100: Train Loss=0.0218, Val Loss=0.2719, Val Acc=0.9390
# Epoch 71/100: Train Loss=0.0117, Val Loss=0.2645, Val Acc=0.9380
# Epoch 72/100: Train Loss=0.0193, Val Loss=0.2693, Val Acc=0.9430
# Epoch 73/100: Train Loss=0.0223, Val Loss=0.2664, Val Acc=0.9390
# Epoch 74/100: Train Loss=0.0156, Val Loss=0.2698, Val Acc=0.9400
# Epoch 75/100: Train Loss=0.0108, Val Loss=0.2653, Val Acc=0.9420
# Epoch 76/100: Train Loss=0.0125, Val Loss=0.2668, Val Acc=0.9430
# Epoch 77/100: Train Loss=0.0115, Val Loss=0.2687, Val Acc=0.9430
# Epoch 78/100: Train Loss=0.0169, Val Loss=0.2740, Val Acc=0.9400
# Epoch 79/100: Train Loss=0.0113, Val Loss=0.2760, Val Acc=0.9360
# Epoch 80/100: Train Loss=0.0128, Val Loss=0.2704, Val Acc=0.9360
# Epoch 81/100: Train Loss=0.0153, Val Loss=0.2725, Val Acc=0.9400
# Epoch 82/100: Train Loss=0.0098, Val Loss=0.2856, Val Acc=0.9400
# Epoch 83/100: Train Loss=0.0086, Val Loss=0.2812, Val Acc=0.9430
# Epoch 84/100: Train Loss=0.0122, Val Loss=0.2769, Val Acc=0.9430
# Epoch 85/100: Train Loss=0.0143, Val Loss=0.2771, Val Acc=0.9400
# Epoch 86/100: Train Loss=0.0166, Val Loss=0.2708, Val Acc=0.9410
# Epoch 87/100: Train Loss=0.0166, Val Loss=0.2693, Val Acc=0.9380
# Epoch 88/100: Train Loss=0.0137, Val Loss=0.2751, Val Acc=0.9370
# Epoch 89/100: Train Loss=0.0166, Val Loss=0.2785, Val Acc=0.9430
# Epoch 90/100: Train Loss=0.0162, Val Loss=0.2732, Val Acc=0.9400
# Epoch 91/100: Train Loss=0.0140, Val Loss=0.2719, Val Acc=0.9410
# Epoch 92/100: Train Loss=0.0185, Val Loss=0.2713, Val Acc=0.9370
# Epoch 93/100: Train Loss=0.0127, Val Loss=0.2789, Val Acc=0.9370
# Epoch 94/100: Train Loss=0.0113, Val Loss=0.2744, Val Acc=0.9410
# Epoch 95/100: Train Loss=0.0145, Val Loss=0.2781, Val Acc=0.9410
# Epoch 96/100: Train Loss=0.0105, Val Loss=0.2855, Val Acc=0.9420
# Epoch 97/100: Train Loss=0.0131, Val Loss=0.2743, Val Acc=0.9430
# Epoch 98/100: Train Loss=0.0116, Val Loss=0.2725, Val Acc=0.9430
# Epoch 99/100: Train Loss=0.0165, Val Loss=0.2764, Val Acc=0.9430
# Epoch 100/100: Train Loss=0.0111, Val Loss=0.2735, Val Acc=0.9420
# Hidden Units=170 -> Val Loss: 0.2263
#
# Running Experiment 3 with hidden units = 200
# Epoch 1/100: Train Loss=3.3176, Val Loss=2.7763, Val Acc=0.1970
# Epoch 2/100: Train Loss=1.8509, Val Loss=1.3284, Val Acc=0.4820
# Epoch 3/100: Train Loss=1.1358, Val Loss=0.8402, Val Acc=0.7690
# Epoch 4/100: Train Loss=0.7845, Val Loss=0.5658, Val Acc=0.8250
# Epoch 5/100: Train Loss=0.5363, Val Loss=0.4324, Val Acc=0.8740
# Epoch 6/100: Train Loss=0.4142, Val Loss=0.3728, Val Acc=0.8990
# Epoch 7/100: Train Loss=0.3589, Val Loss=0.3302, Val Acc=0.9130
# Epoch 8/100: Train Loss=0.2618, Val Loss=0.2910, Val Acc=0.9300
# Epoch 9/100: Train Loss=0.2483, Val Loss=0.2822, Val Acc=0.9280
# Epoch 10/100: Train Loss=0.2225, Val Loss=0.2637, Val Acc=0.9300
# Epoch 11/100: Train Loss=0.1959, Val Loss=0.2544, Val Acc=0.9380
# Epoch 12/100: Train Loss=0.1744, Val Loss=0.2521, Val Acc=0.9370
# Epoch 13/100: Train Loss=0.1770, Val Loss=0.2518, Val Acc=0.9370
# Epoch 14/100: Train Loss=0.1518, Val Loss=0.2437, Val Acc=0.9420
# Epoch 15/100: Train Loss=0.1609, Val Loss=0.2312, Val Acc=0.9380
# Epoch 16/100: Train Loss=0.1195, Val Loss=0.2408, Val Acc=0.9340
# Epoch 17/100: Train Loss=0.1279, Val Loss=0.2431, Val Acc=0.9390
# Epoch 18/100: Train Loss=0.1242, Val Loss=0.2431, Val Acc=0.9330
# Epoch 19/100: Train Loss=0.1155, Val Loss=0.2433, Val Acc=0.9410
# Epoch 20/100: Train Loss=0.1065, Val Loss=0.2332, Val Acc=0.9430
# Epoch 21/100: Train Loss=0.0846, Val Loss=0.2388, Val Acc=0.9390
# Epoch 22/100: Train Loss=0.0936, Val Loss=0.2489, Val Acc=0.9350
# Epoch 23/100: Train Loss=0.0866, Val Loss=0.2464, Val Acc=0.9400
# Epoch 24/100: Train Loss=0.0790, Val Loss=0.2388, Val Acc=0.9380
# Epoch 25/100: Train Loss=0.0814, Val Loss=0.2488, Val Acc=0.9330
# Epoch 26/100: Train Loss=0.0746, Val Loss=0.2542, Val Acc=0.9390
# Epoch 27/100: Train Loss=0.0719, Val Loss=0.2493, Val Acc=0.9380
# Epoch 28/100: Train Loss=0.0736, Val Loss=0.2495, Val Acc=0.9380
# Epoch 29/100: Train Loss=0.0615, Val Loss=0.2461, Val Acc=0.9410
# Epoch 30/100: Train Loss=0.0555, Val Loss=0.2631, Val Acc=0.9370
# Epoch 31/100: Train Loss=0.0717, Val Loss=0.2416, Val Acc=0.9360
# Epoch 32/100: Train Loss=0.0492, Val Loss=0.2375, Val Acc=0.9380
# Epoch 33/100: Train Loss=0.0646, Val Loss=0.2446, Val Acc=0.9390
# Epoch 34/100: Train Loss=0.0510, Val Loss=0.2374, Val Acc=0.9420
# Epoch 35/100: Train Loss=0.0527, Val Loss=0.2409, Val Acc=0.9360
# Epoch 36/100: Train Loss=0.0451, Val Loss=0.2501, Val Acc=0.9360
# Epoch 37/100: Train Loss=0.0533, Val Loss=0.2609, Val Acc=0.9340
# Epoch 38/100: Train Loss=0.0571, Val Loss=0.2593, Val Acc=0.9370
# Epoch 39/100: Train Loss=0.0434, Val Loss=0.2558, Val Acc=0.9330
# Epoch 40/100: Train Loss=0.0386, Val Loss=0.2543, Val Acc=0.9410
# Epoch 41/100: Train Loss=0.0466, Val Loss=0.2644, Val Acc=0.9400
# Epoch 42/100: Train Loss=0.0459, Val Loss=0.2624, Val Acc=0.9370
# Epoch 43/100: Train Loss=0.0508, Val Loss=0.2603, Val Acc=0.9400
# Epoch 44/100: Train Loss=0.0563, Val Loss=0.2617, Val Acc=0.9410
# Epoch 45/100: Train Loss=0.0492, Val Loss=0.2623, Val Acc=0.9370
# Epoch 46/100: Train Loss=0.0368, Val Loss=0.2593, Val Acc=0.9380
# Epoch 47/100: Train Loss=0.0359, Val Loss=0.2560, Val Acc=0.9400
# Epoch 48/100: Train Loss=0.0384, Val Loss=0.2622, Val Acc=0.9410
# Epoch 49/100: Train Loss=0.0451, Val Loss=0.2730, Val Acc=0.9370
# Epoch 50/100: Train Loss=0.0406, Val Loss=0.2605, Val Acc=0.9320
# Epoch 51/100: Train Loss=0.0357, Val Loss=0.2487, Val Acc=0.9370
# Epoch 52/100: Train Loss=0.0401, Val Loss=0.2628, Val Acc=0.9400
# Epoch 53/100: Train Loss=0.0334, Val Loss=0.2722, Val Acc=0.9380
# Epoch 54/100: Train Loss=0.0325, Val Loss=0.2683, Val Acc=0.9410
# Epoch 55/100: Train Loss=0.0308, Val Loss=0.2638, Val Acc=0.9460
# Epoch 56/100: Train Loss=0.0349, Val Loss=0.2643, Val Acc=0.9420
# Epoch 57/100: Train Loss=0.0337, Val Loss=0.2794, Val Acc=0.9390
# Epoch 58/100: Train Loss=0.0268, Val Loss=0.2828, Val Acc=0.9380
# Epoch 59/100: Train Loss=0.0346, Val Loss=0.2728, Val Acc=0.9380
# Epoch 60/100: Train Loss=0.0297, Val Loss=0.2839, Val Acc=0.9400
# Epoch 61/100: Train Loss=0.0231, Val Loss=0.2826, Val Acc=0.9400
# Epoch 62/100: Train Loss=0.0275, Val Loss=0.2785, Val Acc=0.9370
# Epoch 63/100: Train Loss=0.0319, Val Loss=0.2743, Val Acc=0.9410
# Epoch 64/100: Train Loss=0.0203, Val Loss=0.2793, Val Acc=0.9420
# Epoch 65/100: Train Loss=0.0283, Val Loss=0.2790, Val Acc=0.9410
# Epoch 66/100: Train Loss=0.0321, Val Loss=0.2687, Val Acc=0.9400
# Epoch 67/100: Train Loss=0.0365, Val Loss=0.2678, Val Acc=0.9390
# Epoch 68/100: Train Loss=0.0294, Val Loss=0.2781, Val Acc=0.9420
# Epoch 69/100: Train Loss=0.0246, Val Loss=0.2921, Val Acc=0.9400
# Epoch 70/100: Train Loss=0.0305, Val Loss=0.2935, Val Acc=0.9400
# Epoch 71/100: Train Loss=0.0264, Val Loss=0.2783, Val Acc=0.9400
# Epoch 72/100: Train Loss=0.0222, Val Loss=0.2712, Val Acc=0.9410
# Epoch 73/100: Train Loss=0.0241, Val Loss=0.2783, Val Acc=0.9430
# Epoch 74/100: Train Loss=0.0273, Val Loss=0.2830, Val Acc=0.9400
# Epoch 75/100: Train Loss=0.0307, Val Loss=0.2772, Val Acc=0.9380
# Epoch 76/100: Train Loss=0.0237, Val Loss=0.2774, Val Acc=0.9390
# Epoch 77/100: Train Loss=0.0260, Val Loss=0.2778, Val Acc=0.9440
# Epoch 78/100: Train Loss=0.0249, Val Loss=0.2838, Val Acc=0.9450
# Epoch 79/100: Train Loss=0.0207, Val Loss=0.2879, Val Acc=0.9400
# Epoch 80/100: Train Loss=0.0216, Val Loss=0.2805, Val Acc=0.9370
# Epoch 81/100: Train Loss=0.0162, Val Loss=0.2794, Val Acc=0.9390
# Epoch 82/100: Train Loss=0.0234, Val Loss=0.2854, Val Acc=0.9430
# Epoch 83/100: Train Loss=0.0216, Val Loss=0.2882, Val Acc=0.9420
# Epoch 84/100: Train Loss=0.0215, Val Loss=0.2874, Val Acc=0.9380
# Epoch 85/100: Train Loss=0.0257, Val Loss=0.2949, Val Acc=0.9380
# Epoch 86/100: Train Loss=0.0228, Val Loss=0.2852, Val Acc=0.9390
# Epoch 87/100: Train Loss=0.0272, Val Loss=0.2847, Val Acc=0.9390
# Epoch 88/100: Train Loss=0.0159, Val Loss=0.2891, Val Acc=0.9380
# Epoch 89/100: Train Loss=0.0224, Val Loss=0.2933, Val Acc=0.9440
# Epoch 90/100: Train Loss=0.0187, Val Loss=0.2984, Val Acc=0.9430
# Epoch 91/100: Train Loss=0.0164, Val Loss=0.3045, Val Acc=0.9440
# Epoch 92/100: Train Loss=0.0201, Val Loss=0.2978, Val Acc=0.9430
# Epoch 93/100: Train Loss=0.0279, Val Loss=0.2994, Val Acc=0.9460
# Epoch 94/100: Train Loss=0.0106, Val Loss=0.2996, Val Acc=0.9450
# Epoch 95/100: Train Loss=0.0152, Val Loss=0.2965, Val Acc=0.9400
# Epoch 96/100: Train Loss=0.0164, Val Loss=0.2959, Val Acc=0.9400
# Epoch 97/100: Train Loss=0.0202, Val Loss=0.2856, Val Acc=0.9410
# Epoch 98/100: Train Loss=0.0154, Val Loss=0.2814, Val Acc=0.9420
# Epoch 99/100: Train Loss=0.0130, Val Loss=0.2835, Val Acc=0.9400
# Epoch 100/100: Train Loss=0.0099, Val Loss=0.2838, Val Acc=0.9420
# Hidden Units=200 -> Val Loss: 0.2312
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Exp3_ValLoss_HU_10</td><td>▁</td></tr><tr><td>Exp3_ValLoss_HU_100</td><td>▁</td></tr><tr><td>Exp3_ValLoss_HU_130</td><td>▁</td></tr><tr><td>Exp3_ValLoss_HU_170</td><td>▁</td></tr><tr><td>Exp3_ValLoss_HU_200</td><td>▁</td></tr><tr><td>Exp3_ValLoss_HU_30</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▄▄▆▇▇█▁▂▄▄▅▅▅▇▂▂▂▂▃▃▄▄▅█▄▅▆▆▃▆▆▆▇▁▂▃▃▆</td></tr><tr><td>train_accuracy</td><td>▄▅▄▅▅▅▅▅▅▁▇▇██▆▇███████████▆██████▆█████</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▆▆▆▅▅▆▇▃▂▂▂▂▂▁▁▁▁▄▂▁▁▁▃▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▆▇▇▇▇▇▇▇▁██████████████████████████████</td></tr><tr><td>val_loss</td><td>█▆▄▄▄▄▄▁▁▁▂▂▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Exp3_ValLoss_HU_10</td><td>0.49603</td></tr><tr><td>Exp3_ValLoss_HU_100</td><td>0.22846</td></tr><tr><td>Exp3_ValLoss_HU_130</td><td>0.21671</td></tr><tr><td>Exp3_ValLoss_HU_170</td><td>0.2263</td></tr><tr><td>Exp3_ValLoss_HU_200</td><td>0.23124</td></tr><tr><td>Exp3_ValLoss_HU_30</td><td>0.23779</td></tr><tr><td>epoch</td><td>100</td></tr><tr><td>train_accuracy</td><td>0.999</td></tr><tr><td>train_loss</td><td>0.00989</td></tr><tr><td>val_accuracy</td><td>0.942</td></tr><tr><td>val_loss</td><td>0.28377</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vague-elevator-3</strong> at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/xb2kk7ql' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/xb2kk7ql</a><br> View project at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250216_185858-xb2kk7ql/logs</code>

# %% [markdown]
# **RESULT ANALYSIS :**
#
#   This experiment investigated how the number of hidden units in the single hidden layer affects the model’s generalization on the USPS digit recognition task. We evaluated six configurations: 10, 30, 100, 130, 170, and 200 hidden units.
#
# - **Key Observations:**
#   - **Hidden Units = 10:**
#     The model struggled with capacity, resulting in a relatively high validation loss of **0.4960**.
#   - **Hidden Units = 30:**
#     Performance improved substantially, with the validation loss dropping to **0.2378**.
#   - **Hidden Units = 100:**
#     Further improvement was observed (validation loss ≈ **0.2285**), indicating that increased capacity aids learning.
#   - **Hidden Units = 130:**
#     This configuration achieved the best performance with a validation loss of **0.2167**, suggesting an optimal balance between underfitting and overfitting.
#   - **Hidden Units = 170 and 200:**
#     Increasing the hidden units beyond 130 did not yield additional benefits; in fact, the validation loss slightly worsened (≈**0.2263** and **0.2312**, respectively).
#
# - **Overall Assessment:**
#   The training metrics indicate nearly perfect fit (training accuracy ≈99.9% with very low training loss), yet the model generalizes best with **130 hidden units**, as evidenced by the lowest validation loss and a steady validation accuracy (~94.2%). This finding underscores the importance of carefully selecting the model capacity to achieve optimal generalization.
#
# *View detailed run metrics on the wandb dashboard for further insights.*

# %% [markdown]
# ### **D. Early Stopping:**
#    Early stopping is combined with a selected hidden layer size (e.g., 130 units) to further improve generalization.

# %%
# Reinitialize wandb if needed.
if wandb.run is None:
    wandb.init(
        project="usps-digit-classification",
        settings=wandb.Settings(init_timeout=600)
    )

exp4_config = {
    'hidden_units': 130,   # Chosen based on Experiment 3 results.
    'dropout_rate': 0.5,
    'weight_decay': 0.0,
    'learning_rate': 0.40,
    'momentum': 0.9,
    'num_epochs': 100,
    'batch_size': 100,
    'patience': 10         # Early stopping patience.
}

print("\nRunning Experiment 4: Early Stopping")
val_loss_es, epoch_losses_es, epoch_accs_es = run_experiment(exp4_config)
print(f"Experiment 4 Final Validation Loss: {val_loss_es:.4f}")

# (Optional) Locally display the plot:
plt.figure(figsize=(8, 5))
plt.plot(epoch_losses_es, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('Experiment 4: Validation Loss Curve with Early Stopping')
plt.grid(True)
plt.show()

wandb.finish()  # End this run when done.
# Out:
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/content/wandb/run-20250216_190035-rsb212ed</code>
# Syncing run <strong><a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/rsb212ed' target="_blank">comic-lion-4</a></strong> to <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification</a>
#  View run at <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/rsb212ed' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/rsb212ed</a>
# Running Experiment 4: Early Stopping
# Epoch 1/100: Train Loss=2.2840, Val Loss=1.8029, Val Acc=0.3790
# Epoch 2/100: Train Loss=1.3460, Val Loss=0.9250, Val Acc=0.6700
# Epoch 3/100: Train Loss=0.7188, Val Loss=0.4605, Val Acc=0.8480
# Epoch 4/100: Train Loss=0.4633, Val Loss=0.3487, Val Acc=0.8990
# Epoch 5/100: Train Loss=0.3286, Val Loss=0.3082, Val Acc=0.9050
# Epoch 6/100: Train Loss=0.2558, Val Loss=0.2732, Val Acc=0.9240
# Epoch 7/100: Train Loss=0.2425, Val Loss=0.2534, Val Acc=0.9260
# Epoch 8/100: Train Loss=0.2183, Val Loss=0.2463, Val Acc=0.9240
# Epoch 9/100: Train Loss=0.1761, Val Loss=0.2425, Val Acc=0.9290
# Epoch 10/100: Train Loss=0.1657, Val Loss=0.2423, Val Acc=0.9310
# Epoch 11/100: Train Loss=0.1466, Val Loss=0.2518, Val Acc=0.9320
# Epoch 12/100: Train Loss=0.1379, Val Loss=0.2397, Val Acc=0.9270
# Epoch 13/100: Train Loss=0.1238, Val Loss=0.2457, Val Acc=0.9300
# Epoch 14/100: Train Loss=0.1083, Val Loss=0.2372, Val Acc=0.9290
# Epoch 15/100: Train Loss=0.1199, Val Loss=0.2368, Val Acc=0.9310
# Epoch 16/100: Train Loss=0.0967, Val Loss=0.2345, Val Acc=0.9340
# Epoch 17/100: Train Loss=0.1051, Val Loss=0.2480, Val Acc=0.9320
# Epoch 18/100: Train Loss=0.1076, Val Loss=0.2324, Val Acc=0.9320
# Epoch 19/100: Train Loss=0.0931, Val Loss=0.2345, Val Acc=0.9330
# Epoch 20/100: Train Loss=0.0858, Val Loss=0.2282, Val Acc=0.9310
# Epoch 21/100: Train Loss=0.0898, Val Loss=0.2402, Val Acc=0.9310
# Epoch 22/100: Train Loss=0.0710, Val Loss=0.2343, Val Acc=0.9310
# Epoch 23/100: Train Loss=0.0658, Val Loss=0.2296, Val Acc=0.9370
# Epoch 24/100: Train Loss=0.0763, Val Loss=0.2449, Val Acc=0.9340
# Epoch 25/100: Train Loss=0.0570, Val Loss=0.2339, Val Acc=0.9290
# Epoch 26/100: Train Loss=0.0693, Val Loss=0.2450, Val Acc=0.9310
# Epoch 27/100: Train Loss=0.0572, Val Loss=0.2465, Val Acc=0.9310
# Epoch 28/100: Train Loss=0.0567, Val Loss=0.2459, Val Acc=0.9300
# Epoch 29/100: Train Loss=0.0542, Val Loss=0.2420, Val Acc=0.9350
# Epoch 30/100: Train Loss=0.0630, Val Loss=0.2548, Val Acc=0.9330
# Early stopping triggered!
# Experiment 4 Final Validation Loss: 0.2282
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>train_accuracy</td><td>▁▄▆▇▇▇█▇██████████████████████</td></tr><tr><td>train_loss</td><td>█▅▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▇███████████████████████████</td></tr><tr><td>val_loss</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>train_accuracy</td><td>0.978</td></tr><tr><td>train_loss</td><td>0.06304</td></tr><tr><td>val_accuracy</td><td>0.933</td></tr><tr><td>val_loss</td><td>0.25481</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">comic-lion-4</strong> at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/rsb212ed' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification/runs/rsb212ed</a><br> View project at: <a href='https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification' target="_blank">https://wandb.ai/24mcs109-national-institute-of-technology-hamirpur/usps-digit-classification</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250216_190035-rsb212ed/logs</code>

# %% [markdown]
# **RESULT ANALYSIS :**
#
#   This experiment incorporated early stopping to prevent overfitting by halting training once the validation loss stopped improving. Using a configuration with 130 hidden units, a learning rate of 0.40, momentum of 0.9, and a patience of 10 epochs, training was terminated early.
#
# - **Training Dynamics:**
#   The training loss steadily decreased to about **0.063** with a high training accuracy of **97.8%** by epoch 30. Early stopping was triggered at epoch 30, indicating that the model had reached its optimal performance on the validation set.
#
# - **Validation Performance:**
#   The final validation accuracy was approximately **93.3%** with a validation loss of **0.2548**. This suggests that early stopping effectively prevented overfitting while ensuring robust generalization.
#
# - **Overall Assessment:**
#   Early stopping proved to be a valuable strategy in this experiment, as it halted training at the optimal point (epoch 30) before the model began to overfit. The results confirm that integrating early stopping into the training process can help maintain high generalization performance without unnecessary additional training.
#
# *For more detailed run metrics and visualizations, please refer to the wandb dashboard.*

# %% [markdown]
# ## 8. Conclusion
#
# In this practical, we implemented and evaluated a simple neural network for handwritten digit recognition on the USPS dataset. By systematically experimenting with various hyperparameters—including the number of hidden units, learning rate, momentum, dropout, and L2 weight decay—and integrating early stopping, we demonstrated the importance of proper optimization and regularization for improving model generalization. Our findings indicate that a network with approximately 130 hidden units, minimal weight decay, and early stopping achieves an optimal balance between fitting the training data and generalizing to unseen examples, yielding a validation accuracy in the low to mid 90%s.
#
# The use of Weights & Biases (wandb) enabled us to efficiently track, compare, and visualize the performance of multiple experiments, ensuring reproducibility and facilitating data-driven decisions in hyperparameter tuning.

# %% [markdown]
# ## References
#
# 1. Srivastava, N., Hinton, G., Krizhevsky, A., Sutskever, I., & Salakhutdinov, R. (2014). [Dropout: A Simple Way to Prevent Neural Networks from Overfitting](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf). *Journal of Machine Learning Research*, 15(1), 1929-1958.
# 2. Goodfellow, I., Bengio, Y., & Courville, A. (2016). [Deep Learning](https://www.deeplearningbook.org/). MIT Press.
# 3. Weights & Biases Documentation. Retrieved from [https://docs.wandb.ai](https://docs.wandb.ai).
# 4. USPS Dataset on Kaggle. Retrieved from [https://www.kaggle.com/datasets/bistaumanga/usps-dataset](https://www.kaggle.com/datasets/bistaumanga/usps-dataset).
# 5. Bishop, C. M. (2006). *Pattern Recognition and Machine Learning*. Springer.
# 6. Rumelhart, D. E., Hinton, G. E., & Williams, R. J. (1986). *Learning Representations by Back-propagating Errors*. Nature, 323(6088), 533–536.
# 7. Kingma, D. P., & Ba, J. (2014). *Adam: A Method for Stochastic Optimization*. arXiv preprint arXiv:1412.6980.
